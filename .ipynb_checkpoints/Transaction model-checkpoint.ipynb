# %% [markdown]
# # Imports

# %%
from investment.models import Merchant, Transaction, Budget, TransactionSource, CompteDesjardins, VisaDesjardinsTransaction
from investment.processors import CompteDesjardinsPdf, VisaDesjardinsPdfTransactionProcessor
from django.contrib.auth.models import User
from django.utils import timezone
from django.db.models import F

import csv
import chardet



import calendar
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

import random
import numpy as np
import random
import os

user = User.objects.get(id=1)

# %%
def get_file_name(folder_path, file_extention=None):
    
    file_names = [f for f in os.listdir(folder_path) 
                      if os.path.isfile(os.path.join(folder_path, f))]
    if file_extention:
        num_from_end = len(file_extention)
        file_names = [f for f in file_names
                      if f[-num_from_end:] == file_extention]
    return file_names

def delete_files(folder_path, file_names):
    for file in file_names:
        file_name = os.path.join(folder_path, file)
        removed_file_list = []
        try:
            os.remove(file_name)
            print(f"Deleted: {file_name}")
            removed_file_list.append(file_name)
        except Exception as e:
            print(f"Error deleting {file_name}: {e}")
    return removed_file_list

# %% [markdown]
# # Compte Desjardins PDF

# %% [markdown]
# ## Get the file names

# %%
folder_path = "data/Desjardins/comptes"
pdf_to_uplaod = get_file_name(folder_path, "pdf")
pdf_to_uplaod
# Out:
# ['releve_815-30185-0257844-20231001.pdf',
#  'releve_815-30185-0257844-20230901.pdf',
#  'releve_815-30185-0257844-20230801.pdf',
#  'releve_815-30185-0257844-20230201.pdf',
#  'releve_815-30185-0257844-20230401.pdf',
#  'releve_815-30185-0257844-20230601.pdf',
#  'releve_815-30185-0257844-20230101.pdf',
#  'releve_815-30185-0257844-20230301.pdf',
#  'releve_815-30185-0257844-20230701.pdf',
#  'releve_815-30185-0257844-20230501.pdf']

# %% [markdown]
# ## Delete what was previously done#

# %%
# delete uploaded files in media
media_path = "media/Compte Desjardins"
pdf_to_delete = get_file_name(media_path, "pdf")
pdf_to_delete
# deleted_files_list = delete_files(media_path, pdf_to_delete)

# Delete items from uploadedpdf table

# delete privious compte dejardins
c = CompteDesjardins.objects.all()
# c.delete()

# %% [markdown]
# ## Create Compte transactionf

# %%
cdpdf = CompteDesjardins.objects.all()
cdpdf.delete()
folder_path = "data/Desjardins/comptes"
t_list = []
for pdf in pdf_to_uplaod:
    file_path = os.path.join(folder_path, pdf)
    print(file_path)
    p = CompteDesjardinsPdf(file_path, user)
    t_list += p.get_transaction_list()
# Out:
# data/Desjardins/comptes/releve_815-30185-0257844-20231001.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230901.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230801.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230201.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230401.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230601.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230101.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230301.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230701.pdf
# data/Desjardins/comptes/releve_815-30185-0257844-20230501.pdf

# %%
for t in t_list:
    if t.amount:
        t.save()
    else:
        print(t, t.merchant.strip())
# Out:
# 2023-10-26 00:00:00-04:00 -  Paiement facture - AccèsD Internet / Société de l'assurance None Paiement facture - AccèsD Internet / Société de l'assurance
# 2023-09-11 00:00:00-04:00 - Fermeture de compte None Fermeture de compte
# 2023-07-13 00:00:00-04:00 -  Paiement facture - AccèsD Internet / Société de l'assurance None Paiement facture - AccèsD Internet / Société de l'assurance

# %% [markdown]
# # Visa Desjardins

# %% [markdown]
# ## Get the file names

# %%
folder_path = "data/Desjardins/visa"
pdf_to_uplaod = get_file_name(folder_path, "pdf")
pdf_to_uplaod
# Out:
# ['454033600_20230524.pdf',
#  '454033600_20230726.pdf',
#  '454033######600#_20231025.pdf',
#  '454033600_20230623.pdf',
#  '454033######600#_20230323.pdf',
#  '454033600_20230823.pdf',
#  '454033######600#_20230125.pdf',
#  '454033######600#_20230223.pdf',
#  '454033######600#_20230424.pdf',
#  '454033600_20230925.pdf']

# %% [markdown]
# ## Delete what was previously inserted

# %%
v = VisaDesjardinsTransaction.objects.all()
# v.delete()

# %%
len(v)
# Out:
# 580

# %%
t_list = []
for pdf in pdf_to_uplaod:
    file = os.path.join(folder_path, pdf)
    vd = VisaDesjardinsPdfTransactionProcessor(file, user)
    t_list += vd.get_transaction_list()
# Out:
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   25.55 2023-04-25  2023-04-25
# 4         0.005   41.39 2023-04-25  2023-04-25
# 5         0.005   16.95 2023-04-25  2023-04-26
# 6         0.020  107.63 2023-04-28  2023-04-28
# 7         0.005   44.45 2023-04-29  2023-05-01
# 8         0.005   24.67 2023-04-29  2023-05-01
# 9         0.005   17.76 2023-04-29  2023-05-01
# 10        0.005   29.33 2023-04-29  2023-05-01
# 11        0.005   23.54 2023-04-29  2023-05-01
# 12        0.000   14.36 2023-04-29  2023-05-01
# 13        0.005    4.59 2023-05-01  2023-05-01
# 14        0.005    4.99 2023-05-02  2023-05-02
# 15        0.005   78.60 2023-05-04  2023-05-04
# 16        0.005   31.09 2023-05-04  2023-05-04
# 17        0.005   24.57 2023-05-05  2023-05-05
# 18        0.005   14.50 2023-05-06  2023-05-08
#
#                                   merchant
# 3         SUPER C PAT 5963 POINTE AUX TRQC
# 4             MAXI #8987 * POINTE-AUX-TRQC
# 5    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 6        ALLO MON COCO PAT PTE AUX TREMBQC
# 7      SAQ23106CARREFOUR DE LA MONTREAL QC
# 8               BRUNET PLUS ANJOU ANJOU QC
# 9   MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC
# 10             ADONIS 21943 ANJOU ANJOU QC
# 11        SUPER C PAT 5963 POINTE AUX TRQC
# 12              BRUNET PLUS ANJOU ANJOU QC
# 13            MAXI #8987 * POINTE-AUX-TRQC
# 14  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15     SAQ23106CARREFOUR DE LA MONTREAL QC
# 16        SUPER C PAT 5963 POINTE AUX TRQC
# 17  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18     MAXI & CIE REPENTIGNY REPENTIGNY QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   40.28 2023-05-07  2023-05-08
# 4         0.005    7.99 2023-05-07  2023-05-08
# 5         0.005  114.34 2023-05-08  2023-05-08
# 6         0.005    7.98 2023-05-08  2023-05-08
# 7         0.005   37.00 2023-05-10  2023-05-10
# 8         0.005   15.95 2023-05-10  2023-05-10
# 9         0.005   12.33 2023-05-10  2023-05-11
# 10        0.020   19.84 2023-05-10  2023-05-11
# 11        0.005  211.82 2023-05-10  2023-05-12
# 12        0.020   10.86 2023-05-11  2023-05-11
# 13        0.005   21.16 2023-05-13  2023-05-15
# 14        0.005    5.96 2023-05-13  2023-05-15
# 15        0.005    4.99 2023-05-13  2023-05-15
# 16        0.020   55.00 2023-05-14  2023-05-15
# 17        0.005    8.98 2023-05-14  2023-05-15
# 18        0.005   15.95 2023-05-14  2023-05-15
# 19        0.005   16.65 2023-05-15  2023-05-15
# 20        0.005   69.27 2023-05-15  2023-05-15
# 21        0.005   49.25 2023-05-17  2023-05-17
# 22        0.005    1.48 2023-05-17  2023-05-17
# 23        0.005   15.55 2023-05-18  2023-05-18
# 24        0.020   50.24 2023-05-18  2023-05-19
# 25        0.005   30.53 2023-05-19  2023-05-19
# 26        0.005   71.07 2023-05-19  2023-05-19
# 27        0.005    9.52 2023-05-19  2023-05-19
# 28        0.005   69.65 2023-05-19  2023-05-19
# 29        0.020   72.07 2023-05-21  2023-05-23
# 30        0.005  284.78 2023-05-22  2023-05-23
# 31        0.020   20.77 2023-05-22  2023-05-23
# 32        0.005    1.40 2023-05-22  2023-05-23
# 33        0.020   25.30 2023-05-24  2023-05-24
#
#                                     merchant
# 3                 METRO BEAUBIEN MONTREAL QC
# 4                IGA EXTRA 259 ST-LEONARD QC
# 5           SP MONTELLE INTIMATE MONTREAL QC
# 6           SUPER C PAT 5963 POINTE AUX TRQC
# 7        SAQ23106CARREFOUR DE LA MONTREAL QC
# 8        SAQ23106CARREFOUR DE LA MONTREAL QC
# 9                      IGA #8168 MONTREAL QC
# 10                 LE LOUNGE SAINT-SAUVEURQC
# 11       MANOIR SAINT SAUVEUR 450-2271811 QC
# 12       ST-SAU PUB GOURMAND SAINT-SAUVEURQC
# 13              SP JULES & HENRI MONTREAL QC
# 14  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 15    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 16          CAFE LES FRAICHES LASSOMPTION QC
# 17       MAXI & CIE REPENTIGNY REPENTIGNY QC
# 18         SAQ23070 REPENTIGNY REPENTIGNY QC
# 19    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 20          SUPER C PAT 5963 POINTE AUX TRQC
# 21       SAQ23106CARREFOUR DE LA MONTREAL QC
# 22            APPLE.COM/BILL 866-712-7753 ON
# 23       SAQ23106CARREFOUR DE LA MONTREAL QC
# 24          LES INSULAIRES MICROBRA LAVAL QC
# 25    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 26          SUPER C PAT 5963 POINTE AUX TRQC
# 27                  MAXI #8622 TERREBONNE QC
# 28                      SAQ23004 BROSSARD QC
# 29          MICROBRASSERIE LA MEMPH MAGOG QC
# 30                      RW #2499 MONTREAL QC
# 31     MCDONALD'S #18127 QPS ANGE-GARDIEN QC
# 32      AGENCE DE MOBILITE DURABLMONTREAL QC
# 33           LE POKE STATION PAT MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.020    3.50 2023-06-26  2023-06-27
# 4         0.020   79.34 2023-06-27  2023-06-28
# 5         0.020   68.76 2023-06-29  2023-06-29
# 6         0.005   68.77 2023-06-30  2023-06-30
# 7         0.005   17.33 2023-06-30  2023-06-30
# 8         0.005    5.46 2023-06-30  2023-06-30
# 9         0.005    8.26 2023-07-02  2023-07-04
# 10        0.005   24.14 2023-07-02  2023-07-04
# 11        0.005   10.11 2023-07-02  2023-07-04
# 12        0.005   26.95 2023-07-02  2023-07-04
# 13        0.005    6.27 2023-07-04  2023-07-04
# 14        0.005  344.37 2023-07-06  2023-07-06
# 15        0.005  446.69 2023-07-06  2023-07-06
# 16        0.005   24.72 2023-07-06  2023-07-07
# 17        0.005   37.81 2023-07-07  2023-07-07
# 18        0.005   14.70 2023-07-07  2023-07-07
#
#                                     merchant
# 3             STM LAURIER DIN101 MONTREAL QC
# 4                      CANAILLES MONTREAL QC
# 5         GASTON RESTAURANT APPO MONTREAL QC
# 6           SUPER C PAT 5963 POINTE AUX TRQC
# 7       PHARMACIE VINH THE JIMMY MONTREAL QC
# 8           CHEZ BAPTISTE MASSON MONTREAL QC
# 9   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 10             DOLLARAMA # 285 REPENTIGNY QC
# 11              JEAN COUTU 046 REPENTIGNY QC
# 12              MAXI #8987 * POINTE-AUX-TRQC
# 13    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 14          OLDNAVY.COM 2944 505-462-0076 ON
# 15         AIRBNB * HMT2PREXQ8 AIRBNB.COM GB
# 16                     IGA #8168 MONTREAL QC
# 17    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18              MAXI #8987 * POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   60.53 2023-07-07  2023-07-07
# 4         0.005    8.05 2023-07-07  2023-07-07
# 5         0.020   20.00 2023-07-08  2023-07-10
# 6         0.005  149.46 2023-07-08  2023-07-10
# 7         0.005  122.60 2023-07-09  2023-07-10
# ..          ...     ...        ...         ...
# 60        0.005   11.28 2023-07-22  2023-07-24
# 61        0.005   10.75 2023-07-23  2023-07-24
# 62        0.005   22.30 2023-07-23  2023-07-24
# 63        0.005   13.23 2023-07-23  2023-07-24
# 64        0.005   29.85 2023-07-23  2023-07-24
#
#                                   merchant
# 3         SUPER C PAT 5963 POINTE AUX TRQC
# 4                    IGA #8168 MONTREAL QC
# 5        LE CIRCUIT ELECTRIQUE MONTREAL QC
# 6             #414 SPORTS EXPERTS ANJOU QC
# 7              Nespresso Canada Toronto ON
# ..                                     ...
# 60  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 61            SEPAQ YAMASKA ROXTON POND QC
# 62            SEPAQ YAMASKA ROXTON POND QC
# 63            SEPAQ YAMASKA ROXTON POND QC
# 64          SEPAQ 1 800 665 6527 QUEBEC QC
#
# [62 rows x 5 columns]
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   19.10 2023-07-23  2023-07-24
# 4         0.005   35.11 2023-07-23  2023-07-24
# 5         0.005   18.15 2023-07-23  2023-07-24
# 6         0.005   12.96 2023-07-24  2023-07-24
# 7         0.005   29.90 2023-07-24  2023-07-25
# 8         0.005   40.17 2023-07-25  2023-07-25
# 9         0.005   48.30 2023-07-26  2023-07-26
# 10        0.005  186.64 2023-07-26  2023-07-26
# 11        0.005    6.79 2023-07-26  2023-07-26
#
#                               merchant
# 3          SEPAQ 1 800 665 6527 QUEBEC
# 4            METRO PLOUFFE MAGOG MAGOG
# 5                 SAQ23082 MAGOG MAGOG
# 6            METRO PLOUFFE MAGOG MAGOG
# 7                 SAQ23082 MAGOG MAGOG
# 8   MICROBRASSERIE COATICOOK COATICOOK
# 9                          DVERT MAGOG
# 10             REITMANS #1499 MONTREAL
# 11           METRO PLOUFFE MAGOG MAGOG
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005  181.54 2023-09-28  2023-09-28
# 4         0.005   50.53 2023-09-28  2023-09-28
# 5         0.005    5.29 2023-09-30  2023-10-02
# 6         0.020   68.30 2023-10-02  2023-10-02
# 7         0.020    2.42 2023-10-02  2023-10-02
# 8         0.020    6.89 2023-10-03  2023-10-03
# 9         0.005   79.18 2023-10-03  2023-10-03
# 10        0.005   30.19 2023-10-04  2023-10-04
# 11        0.005  138.68 2023-10-04  2023-10-05
# 12        0.020   16.03 2023-10-07  2023-10-10
# 13        0.005   35.00 2023-10-08  2023-10-10
# 14        0.020   57.00 2023-10-08  2023-10-10
# 15        0.020    5.25 2023-10-08  2023-10-10
# 16        0.020   18.84 2023-10-09  2023-10-10
# 17        0.005  122.14 2023-10-11  2023-10-11
# 18        0.005    1.48 2023-10-17  2023-10-17
#
#                                     merchant
# 3     AMZN Mktp CA*T16F392L0 WWW.AMAZON.CAON
# 4     AMZN Mktp CA*T10UZ0KR0 WWW.AMAZON.CAON
# 5   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 6            LE POKE STATION PAT MONTREAL QC
# 7              TIM HORTONS #1151 MONTREAL QC
# 8                NETFLIX.COM 866-716-0414 ON
# 9     AMZN Mktp CA*T98OL3ZE1 WWW.AMAZON.CAON
# 10                      FOODHERO MONTREAL QC
# 11                   SAQ.COM/12424 QUEBEC QC
# 12                     LA STATION EASTMAN QC
# 13                PERFECTION.CA LONGUEUIL QC
# 14          CAFE LES FRAICHES LASSOMPTION QC
# 15                   PASTA AND FUMO MAGOG QC
# 16                 LA MIE D'ORFORD ORFORD QC
# 17    GLOBO CANADA- E-COMMER SAINT- LAURENQC
# 18            APPLE.COM/BILL 866-712-7753 ON
#    BONIDOLLARS  amount       date record_date  \
# 3        0.005  114.00 2023-10-19  2023-10-19
# 4        0.005   20.98 2023-10-25  2023-10-25
# 5        0.005   45.70 2023-10-25  2023-10-25
#
#                                    merchant
# 3  SERVICE CANADA PT AUX TR PT AUX TREMB QC
# 4                      FOODHERO MONTREAL QC
# 5                   COBIEBOUTIQUE LONDON GB
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   57.23 2023-05-25  2023-05-25
# 4         0.005   16.95 2023-05-26  2023-05-26
# 5         0.005   49.45 2023-05-27  2023-05-29
# 6         0.020    9.00 2023-05-27  2023-05-29
# 7         0.005   41.49 2023-05-27  2023-05-29
# 8         0.000  101.04 2023-05-27  2023-05-29
# 9         0.005   11.47 2023-05-31  2023-05-31
# 10        0.005   29.60 2023-05-31  2023-06-01
# 11        0.005    7.38 2023-06-01  2023-06-01
# 12        0.020   25.43 2023-06-01  2023-06-01
# 13        0.020   10.58 2023-06-01  2023-06-01
# 14        0.005   14.08 2023-06-01  2023-06-01
# 15        0.020   15.00 2023-06-01  2023-06-02
# 16        0.005   34.44 2023-06-02  2023-06-02
# 17        0.020   13.55 2023-06-02  2023-06-02
# 18        0.005   17.95 2023-06-03  2023-06-05
#
#                                  merchant
# 3        SUPER C PAT 5963 POINTE AUX TRQC
# 4     SAQ23106CARREFOUR DE LA MONTREAL QC
# 5     SAQ23106CARREFOUR DE LA MONTREAL QC
# 6    SQ *LA BUVETTE DU QUAI PAMontreal QC
# 7        SUPER C PAT 5963 POINTE AUX TRQC
# 8                 RW & CO. #2216 ANJOU QC
# 9            MAXI #8987 * POINTE-AUX-TRQC
# 10      SAQ23327 REPENTIGNY REPENTIGNY QC
# 11            SHELL C81389 CHARLEMAGNE QC
# 12            LES TROIS GARCONS QUEBEC QC
# 13            LES TROIS GARCONS QUEBEC QC
# 14             MARCHE RICHELIEU QUEBEC QC
# 15  STARBUCKS COFFEE # 599 CHARLEMAGNE QC
# 16     LA MAISON SIMONS INC(QUE)QUEBEC QC
# 17               PUB ST-PATRICK QUEBEC QC
# 18    SAQ23106CARREFOUR DE LA MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005    4.60 2023-06-03  2023-06-05
# 4         0.005  144.82 2023-06-03  2023-06-05
# 5         0.005    6.31 2023-06-03  2023-06-05
# 6         0.020   13.89 2023-06-03  2023-06-05
# 7         0.020  133.21 2023-06-04  2023-06-05
# 9         0.005   67.40 2023-06-04  2023-06-05
# 10        0.005   12.81 2023-06-04  2023-06-05
# 11        0.005   30.53 2023-06-04  2023-06-05
# 12        0.005   25.83 2023-06-04  2023-06-05
# 13        0.005   20.68 2023-06-05  2023-06-05
# 14        0.005   33.22 2023-06-05  2023-06-05
# 15        0.005    8.94 2023-06-05  2023-06-05
# 16        0.000  126.28 2023-06-06  2023-06-06
# 18        0.005   40.22 2023-06-07  2023-06-07
# 19        0.005   24.10 2023-06-08  2023-06-08
# 20        0.005    8.48 2023-06-08  2023-06-08
# 21        0.005   16.95 2023-06-09  2023-06-09
# 22        0.005   21.28 2023-06-09  2023-06-09
# 23        0.005   49.86 2023-06-09  2023-06-09
# 24        0.005   11.17 2023-06-09  2023-06-09
# 25        0.005   57.48 2023-06-10  2023-06-12
# 26        0.005   30.55 2023-06-10  2023-06-12
# 27        0.020   15.23 2023-06-10  2023-06-12
# 28        0.020   13.00 2023-06-10  2023-06-12
# 29        0.005   24.38 2023-06-11  2023-06-12
# 30        0.005   11.27 2023-06-11  2023-06-12
# 31        0.005    5.99 2023-06-11  2023-06-12
# 32        0.005   10.18 2023-06-12  2023-06-13
# 33        0.005   59.70 2023-06-13  2023-06-13
# 34        0.005    4.04 2023-06-14  2023-06-14
# 35        0.005   18.15 2023-06-15  2023-06-15
# 36        0.005   18.16 2023-06-15  2023-06-15
# 37        0.005   18.84 2023-06-15  2023-06-16
# 38        0.005   10.00 2023-06-15  2023-06-16
# 39        0.020   60.61 2023-06-15  2023-06-16
# 40        0.005   20.76 2023-06-15  2023-06-16
# 41        0.020   28.98 2023-06-16  2023-06-16
# 42        0.005    5.29 2023-06-16  2023-06-16
# 43        0.005    2.99 2023-06-16  2023-06-16
# 44        0.005    4.07 2023-06-16  2023-06-16
# 45        0.005   58.10 2023-06-16  2023-06-16
# 46        0.005    1.48 2023-06-17  2023-06-19
# 47        0.005  235.85 2023-06-17  2023-06-19
# 48        0.005    3.44 2023-06-19  2023-06-19
# 49        0.005    7.99 2023-06-19  2023-06-19
# 50        0.005   15.42 2023-06-19  2023-06-19
# 51        0.005   59.59 2023-06-19  2023-06-19
# 52        0.005   54.46 2023-06-19  2023-06-19
# 53        0.005    5.00 2023-06-20  2023-06-20
# 54        0.005   13.96 2023-06-20  2023-06-20
# 55        0.000   37.96 2023-06-20  2023-06-20
# 56        0.005   10.11 2023-06-20  2023-06-21
# 57        0.005   98.20 2023-06-22  2023-06-22
# 58        0.005   24.67 2023-06-22  2023-06-22
# 59        0.005    5.26 2023-06-22  2023-06-23
#
#                                   merchant
# 3          DOLLARAMA #1362 POINTE-AUX-TRQC
# 4       TUANGO INC/#LD-0063868 MONTREAL QC
# 5     PHARMACIE VINH THE JIMMY MONTREAL QC
# 6           MCDONALD'S #11258 DONNACONA QC
# 7               Prezi, Inc. 415-4948313 CA
# 9      SAQ23106CARREFOUR DE LA MONTREAL QC
# 10  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11        SUPER C PAT 5963 POINTE AUX TRQC
# 12                   IGA #8168 MONTREAL QC
# 13  AMZN Mktp CA*VW5AP2J43 WWW.AMAZON.CAON
# 14  AMZN Mktp CA*156UA1NW3 WWW.AMAZON.CAON
# 15             ADONIS 21943 ANJOU ANJOU QC
# 16              Prezi, Inc. 415-4948313 CA
# 18  AMZN Mktp CA*CR18X5CT3 WWW.AMAZON.CAON
# 19        Amazon.ca*KP8828J23 AMAZON.CA ON
# 20  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 21     SAQ23106CARREFOUR DE LA MONTREAL QC
# 22            MAXI #8987 * POINTE-AUX-TRQC
# 23        SUPER C PAT 5963 POINTE AUX TRQC
# 24            MAXI #8987 * POINTE-AUX-TRQC
# 25                 WINNERS 474 MONTREAL QC
# 26     SAQ23106CARREFOUR DE LA MONTREAL QC
# 27                 SMOKING BBQ MONTREAL QC
# 28     STM LOGE LANGELIER N101 MONTREAL QC
# 29                    FOODHERO MONTREAL QC
# 30       AUX P'TITS BOCAUX POINTE AUX TRQC
# 31                   IGA #8168 MONTREAL QC
# 32                   IGA #8168 MONTREAL QC
# 33     SAQ23011 HALLES D'ANJOU MONTREAL QC
# 34            MAXI #8987 * POINTE-AUX-TRQC
# 35     SAQ23106CARREFOUR DE LA MONTREAL QC
# 36        SUPER C PAT 5963 POINTE AUX TRQC
# 37                   IGA #8168 MONTREAL QC
# 38    AGENCE DE MOBILITE DURABLMONTREAL QC
# 39               PETITE MARCHE MONTREAL QC
# 40  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 41                    CAFE ISO MONTREAL QC
# 42            LA MARCHE A COTE Montreal QC
# 43            METRO PLOUFFE MAGOG MAGOG QC
# 44    AGENCE DE MOBILITE DURABLMONTREAL QC
# 45                 SAQ23082 MAGOG MAGOG QC
# 46          APPLE.COM/BILL 866-712-7753 ON
# 47                 SAQ.COM/12424 QUEBEC QC
# 48            CPC / SCP 227730 MONTRÉAL QC
# 49             ADONIS 21943 ANJOU ANJOU QC
# 50  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 51        SUPER C PAT 5963 POINTE AUX TRQC
# 52            MAXI #8987 * POINTE-AUX-TRQC
# 53             ADONIS 21943 ANJOU ANJOU QC
# 54            MAXI #8987 * POINTE-AUX-TRQC
# 55            MAXI #8987 * POINTE-AUX-TRQC
# 56    PHARMACIE VINH THE JIMMY MONTREAL QC
# 57     SAQ23106CARREFOUR DE LA MONTREAL QC
# 58        SUPER C PAT 5963 POINTE AUX TRQC
# 59                   IGA #8168 MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.020   52.89 2023-02-24  2023-02-24
# 4         0.005    6.02 2023-02-24  2023-02-24
# 5         0.005    8.05 2023-02-25  2023-02-27
# 6         0.020  227.93 2023-02-26  2023-02-27
# 7         0.005    2.00 2023-03-01  2023-03-01
# 8         0.005    9.21 2023-03-01  2023-03-01
# 9         0.005   37.50 2023-03-02  2023-03-02
# 10        0.005   40.23 2023-03-04  2023-03-06
# 11        0.005   30.00 2023-03-04  2023-03-06
# 12        0.005   51.50 2023-03-04  2023-03-06
# 13        0.005    9.12 2023-03-07  2023-03-07
# 14        0.005   56.08 2023-03-07  2023-03-07
# 15        0.005   12.42 2023-03-07  2023-03-07
# 16        0.005   23.40 2023-03-09  2023-03-10
# 17        0.005   25.20 2023-03-09  2023-03-10
# 18        0.005   31.97 2023-03-10  2023-03-10
#
#                                     merchant
# 3                   PIAZZETTA MAGOG MAGOG QC
# 4               METRO PLOUFFE MAGOG MAGOG QC
# 5               PROXI EXTRA ORFORD ORFORD QC
# 6                  L'HELICOPTERE MONTREAL QC
# 7       AGENCE DE MOBILITE DURABLMONTREAL QC
# 8     METRO DE LA ROUSSELIER POINTE AUX TRQC
# 9   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 10  LES ANIMALERIES T.D. ZOO POINTE-AUX-TRQC
# 11     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 12          SUPER C PAT 5963 POINTE AUX TRQC
# 13       MAXI & CIE REPENTIGNY REPENTIGNY QC
# 14          SUPER C REPENTIGNY REPENTIGNY QC
# 15      METRO MARQUIS REPENTIG REPENTIGNY QC
# 16     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17                       LE DATE MONTREAL QC
# 18    METRO DE LA ROUSSELIER POINTE AUX TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   65.77 2023-03-10  2023-03-10
# 4         0.005   43.35 2023-03-10  2023-03-10
# 5         0.005   43.91 2023-03-11  2023-03-13
# 6         0.005  126.00 2023-03-11  2023-03-13
# 7         0.005    3.77 2023-03-11  2023-03-13
# 8         0.020   30.00 2023-03-12  2023-03-13
# 9         0.020   32.06 2023-03-12  2023-03-13
# 10        0.005    7.00 2023-03-14  2023-03-14
# 11        0.005  111.68 2023-03-14  2023-03-14
# 12        0.020   78.00 2023-03-16  2023-03-16
# 13        0.005   18.90 2023-03-16  2023-03-17
# 14        0.005   32.90 2023-03-18  2023-03-20
# 15        0.005   28.75 2023-03-18  2023-03-20
# 16        0.005   27.95 2023-03-18  2023-03-20
# 17        0.005    5.92 2023-03-19  2023-03-20
# 18        0.005   33.18 2023-03-19  2023-03-20
# 19        0.005    7.87 2023-03-19  2023-03-20
#
#                                     merchant
# 3           SUPER C PAT 5963 POINTE AUX TRQC
# 4               MAXI #8987 * POINTE-AUX-TRQC
# 5                      ADONIS ANJOU ANJOU QC
# 6        NBX*CENTRECOMROUSSIN 514-6454519 QC
# 7          SAQ23327 REPENTIGNY REPENTIGNY QC
# 8           CAFE LES FRAICHES LASSOMPTION QC
# 9                   DUNNS FAMOUS MONTREAL QC
# 10    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11         AIRBNB * HMT2PREXQ8 AIRBNB.COM GB
# 12  ERABLIERE AU RYTHME DES TSAINT-LIN-LAUQC
# 13     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 14          SUPER C PAT 5963 POINTE AUX TRQC
# 15              MAXI #8987 * POINTE-AUX-TRQC
# 16     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17    MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC
# 18          SUPER C PAT 5963 POINTE AUX TRQC
# 19                     ADONIS ANJOU ANJOU QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   32.65 2023-07-26  2023-07-27
# 4         0.020   64.46 2023-07-27  2023-07-27
# 5         0.005   17.24 2023-07-27  2023-07-27
# 6         0.005   38.20 2023-07-28  2023-07-28
# 7         0.005   29.14 2023-07-28  2023-07-28
# 8         0.005   10.57 2023-07-28  2023-07-28
# 9         0.000   68.94 2023-07-28  2023-07-28
# 10        0.005    9.15 2023-07-29  2023-07-31
# 11        0.005   26.85 2023-07-30  2023-07-31
# 12        0.020   75.37 2023-07-30  2023-07-31
# 13        0.005    4.29 2023-07-31  2023-07-31
# 14        0.020    4.44 2023-07-31  2023-08-01
# 15        0.005   24.47 2023-08-01  2023-08-01
# 16        0.005  137.13 2023-08-01  2023-08-01
# 17        0.005   10.57 2023-08-02  2023-08-02
# 18        0.005   21.92 2023-08-02  2023-08-02
#
#                                     merchant
# 3                    SAQ23082 MAGOG MAGOG QC
# 4              L'OEUFRIER BROMONT BROMONT QC
# 5             JEAN COUTU 045 POINTE AUX TRQC
# 6             SEPAQ 1 800 665 6527 QUEBEC QC
# 7           SUPER C PAT 5963 POINTE AUX TRQC
# 8                      IGA #8168 MONTREAL QC
# 9                REITMANS #443 REPENTIGNY QC
# 10     SUPER C B ST PAUL 261 BAIE SAINT PAQC
# 11             SAQ33532 CLERMONT CLERMONT QC
# 12         PIZZERIA DU BOULEVARD CLERMONT QC
# 13        MARCHE NOTRE DAME 2225 MONTREAL QC
# 14     MCDONALD'S #10630 Q04 BERTHIERVILLEQC
# 15  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 16     LE PAPETIER LE LIBRAIRE REPENTIGNY QC
# 17  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 18          SUPER C PAT 5963 POINTE AUX TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005  153.20 2023-08-02  2023-08-03
# 4         0.005   59.55 2023-08-03  2023-08-03
# 5         0.005   15.82 2023-08-03  2023-08-04
# 6         0.005   39.98 2023-08-03  2023-08-04
# 7         0.005   40.20 2023-08-04  2023-08-04
# 8         0.005   16.95 2023-08-04  2023-08-04
# 9         0.005   55.12 2023-08-06  2023-08-07
# 10        0.005   27.15 2023-08-06  2023-08-07
# 11        0.005   63.35 2023-08-07  2023-08-07
# 12        0.005    8.41 2023-08-07  2023-08-07
# 13        0.005    4.98 2023-08-07  2023-08-08
# 14        0.000    0.95 2023-08-08  2023-08-08
# 15        0.005   21.24 2023-08-09  2023-08-09
# 16        0.005    9.89 2023-08-11  2023-08-11
# 17        0.005   53.23 2023-08-11  2023-08-11
# 18        0.005   26.57 2023-08-12  2023-08-14
# 19        0.005   24.11 2023-08-12  2023-08-14
# 20        0.005   11.28 2023-08-12  2023-08-14
# 21        0.020   50.00 2023-08-13  2023-08-14
# 22        0.005    4.13 2023-08-14  2023-08-14
# 23        0.020   46.28 2023-08-14  2023-08-14
# 24        0.005    7.60 2023-08-15  2023-08-15
# 25        0.005   15.88 2023-08-15  2023-08-15
# 26        0.005    1.48 2023-08-17  2023-08-17
# 27        0.005   23.43 2023-08-17  2023-08-17
# 28        0.005   91.90 2023-08-18  2023-08-18
# 29        0.005    6.99 2023-08-18  2023-08-18
# 30        0.005   49.34 2023-08-19  2023-08-21
# 31        0.005    4.07 2023-08-19  2023-08-21
# 32        0.005   95.64 2023-08-20  2023-08-21
# 33        0.005   19.99 2023-08-20  2023-08-21
# 34        0.005  142.24 2023-08-22  2023-08-22
# 35        0.005   34.47 2023-08-22  2023-08-22
# 36        0.005    4.29 2023-08-22  2023-08-22
# 37        0.005  229.95 2023-08-23  2023-08-23
#
#                                   merchant
# 3                  SAQ.COM/12424 QUEBEC QC
# 4   SAQ23303 TERREBONNE-MTEE TERREBONNE QC
# 5           IGA EXTRA # 8528 TERREBONNE QC
# 6                  MAXI #8622 LACHENAIE QC
# 7        LA MAISON SIMONS INC (ANJANJOU QC
# 8      SAQ23106CARREFOUR DE LA MONTREAL QC
# 9   AMZN Mktp CA*TA84J1ZZ1 WWW.AMAZON.CAON
# 10                        ETSY ETSY.COM IE
# 11     SAQ23106CARREFOUR DE LA MONTREAL QC
# 12        SUPER C PAT 5963 POINTE AUX TRQC
# 13                   IGA #8168 MONTREAL QC
# 14  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15    AU COIN DU PEDALEUR ET REPENTIGNY QC
# 16            METRO FOGARTY CHARLEMAGNE QC
# 17        ESSO COUCHE-TARD SAINT-LAMBERTQC
# 18  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 19        SUPER C PAT 5963 POINTE AUX TRQC
# 20    PROVIGO LE GARDEUR #85 LE GARDEUR QC
# 21         CDNCANCERSOC-DR 888-955-5455 ON
# 22           PETRO CANADA14110 MONTREAL QC
# 23         LE POKE STATION PAT MONTREAL QC
# 24             RACEROSTER PRISON LONDON ON
# 25                    FOODHERO MONTREAL QC
# 26          APPLE.COM/BILL 866-712-7753 ON
# 27  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 28        SUPER C PAT 5963 POINTE AUX TRQC
# 29                   IGA #8168 MONTREAL QC
# 30  AMZN Mktp CA*TQ7D69XB2 WWW.AMAZON.CAON
# 31    AGENCE DE MOBILITE DURABLMONTREAL QC
# 32  AMZN Mktp CA*TQ5FP7010 WWW.AMAZON.CAON
# 33  AMZN Mktp CA*TQ0828ME2 WWW.AMAZON.CAON
# 34                    RW #2499 MONTREAL QC
# 35          JEAN COUTU 045 POINTE AUX TRQC
# 36              MAXI #8987 POINTE-AUX-TRQC
# 37    SQ *9483-1104 QUEBEC INC.LANORAIE QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   25.00 2023-12-24  2023-12-27
# 4         0.005   53.25 2023-12-24  2023-12-27
# 5         0.020   28.63 2023-12-26  2023-12-27
# 6         0.005   68.39 2023-12-26  2023-12-27
# 7         0.005   53.94 2023-12-26  2023-12-27
# 8         0.020   71.60 2023-12-26  2023-12-27
# 9         0.005   56.75 2023-12-26  2023-12-27
# 10        0.005   34.23 2023-12-27  2023-12-27
# 11        0.005   80.65 2023-12-27  2023-12-28
# 12        0.020  113.96 2023-12-28  2023-12-28
# 13        0.005    5.69 2023-12-28  2023-12-29
# 14        0.005   12.56 2023-12-29  2023-12-29
# 15        0.005   43.63 2023-12-30  2023-12-30
# 16        0.005   14.95 2023-12-31  2023-01-03
# 17        0.005   22.77 2023-12-31  2023-01-03
# 18        0.005   21.60 2023-12-31  2023-01-03
#
#                                   merchant
# 3         Amazon.ca*SD6270PY3 AMAZON.CA ON
# 4    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 5    PETIT QUEBEC REPENTIGNY REPENTIGNY QC
# 6   AMZN Mktp CA*AS0TR8WS3 WWW.AMAZON.CAON
# 7         SUPER C REPENTIGNY REPENTIGNY QC
# 8       METRO EN LIGNE 2445 SAINTE ROSE QC
# 9        SAQ23070 REPENTIGNY REPENTIGNY QC
# 10  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11            SAQ23199 SAQ.COM MONTREAL QC
# 12      HENRI BRASSERIE FRANCA MONTREAL QC
# 13    AGENCE DE MOBILITE DURABLMONTREAL QC
# 14        SUPER C PAT 5963 POINTE AUX TRQC
# 15          LE DIVINS TANDEM TERREBONNE QC
# 16  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 17        SUPER C PAT 5963 POINTE AUX TRQC
# 18            MAXI #8987 * POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   24.99 2023-12-31  2023-01-03
# 4         0.005    4.60 2023-12-31  2023-01-03
# 5         0.005   16.78 2023-01-04  2023-01-04
# 6         0.000    0.25 2023-01-04  2023-01-04
# 7         0.005   37.93 2023-01-06  2023-01-06
# 8         0.005    8.48 2023-01-06  2023-01-06
# 9         0.005   34.35 2023-01-06  2023-01-06
# 10        0.005   25.00 2023-01-06  2023-01-06
# 11        0.005  183.96 2023-01-07  2023-01-09
# 12        0.005   31.50 2023-01-07  2023-01-09
# 13        0.005   30.03 2023-01-07  2023-01-09
# 14        0.005    4.03 2023-01-08  2023-01-09
# 15        0.005   14.35 2023-01-08  2023-01-09
# 16        0.005    7.98 2023-01-10  2023-01-10
# 17        0.005   26.72 2023-01-10  2023-01-10
# 18        0.005  252.95 2023-01-12  2023-01-12
# 19        0.005   18.18 2023-01-13  2023-01-13
# 20        0.005   32.71 2023-01-14  2023-01-16
# 21        0.020   82.12 2023-01-14  2023-01-16
# 22        0.005   14.74 2023-01-14  2023-01-16
# 23        0.005   21.14 2023-01-14  2023-01-16
# 24        0.005   11.86 2023-01-14  2023-01-16
# 25        0.020   51.14 2023-01-19  2023-01-19
# 26        0.005   11.69 2023-01-20  2023-01-20
# 27        0.005  155.16 2023-01-21  2023-01-23
# 28        0.005   13.85 2023-01-21  2023-01-23
# 29        0.005    8.43 2023-01-21  2023-01-23
# 30        0.005   10.61 2023-01-21  2023-01-23
# 31        0.005   29.52 2023-01-22  2023-01-23
# 32        0.005   27.32 2023-01-23  2023-01-23
# 33        0.005   16.87 2023-01-24  2023-01-24
#
#                                     merchant
# 3                      IGA #8168 MONTREAL QC
# 4        WAL-MART STORE#1169 POINTE-AUX-TRQC
# 5                       Billabong Halifax NS
# 6       AGENCE DE MOBILITE DURABLMONTREAL QC
# 7   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 8        LIBRAIRIE RENAUD BRAY REPENTIGNY QC
# 9           SUPER C REPENTIGNY REPENTIGNY QC
# 10     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 11             SP YUL RUN CANADA MONTREAL QC
# 12    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 13                     IGA #8168 MONTREAL QC
# 14          SUPER C PAT 5963 POINTE AUX TRQC
# 15     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 16              MAXI #8987 * POINTE-AUX-TRQC
# 17                     ADONIS ANJOU ANJOU QC
# 18                   HORIZON ROC MONTREAL QC
# 19                      FOODHERO MONTREAL QC
# 20              MAXI #8987 * POINTE-AUX-TRQC
# 21                  RESTO INDIAN MONTREAL QC
# 22                     IGA #8168 MONTREAL QC
# 23    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 24          SUPER C PAT 5963 POINTE AUX TRQC
# 25          POKE STATION PAT POINTE-AUX-TRBC
# 26    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 27                GLOBOSHOES.COM MONTREAL QC
# 28        SUPER C ST LEONARD SAINT LEONARDQC
# 29                     ADONIS ANJOU ANJOU QC
# 30    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 31          SUPER C PAT 5963 POINTE AUX TRQC
# 32                     ADONIS ANJOU ANJOU QC
# 33              PHARMAPRIX #0061 MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   82.68 2023-01-28  2023-01-30
# 4         0.005   10.58 2023-01-28  2023-01-30
# 5         0.005   38.98 2023-01-28  2023-01-30
# 6         0.000   68.65 2023-01-28  2023-01-30
# 7         0.005   30.85 2023-01-29  2023-01-30
# 8         0.005   66.52 2023-01-29  2023-01-30
# 9         0.005   39.12 2023-01-29  2023-01-30
# 10        0.005   21.58 2023-01-30  2023-01-30
# 11        0.005   81.61 2023-01-30  2023-01-30
# 12        0.005  103.46 2023-02-04  2023-02-06
# 13        0.005   18.87 2023-02-04  2023-02-06
# 14        0.005   11.58 2023-02-05  2023-02-06
# 15        0.005   12.51 2023-02-05  2023-02-06
# 16        0.005   55.72 2023-02-06  2023-02-06
# 17        0.005  216.29 2023-02-07  2023-02-08
# 18        0.020   33.72 2023-02-09  2023-02-09
#
#                                   merchant
# 3      SP MONSIEUR COCKTAIL QUEBEC CITY QC
# 4                    ADONIS ANJOU ANJOU QC
# 5   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 6                  GLOBO #4534 MONTREAL QC
# 7   AMZN Mktp CA*1F3HO5IV3 WWW.AMAZON.CAON
# 8         SUPER C PAT 5963 POINTE AUX TRQC
# 9             MAXI #8987 * POINTE-AUX-TRQC
# 10  AMZN Mktp CA*5002Y9IQ3 WWW.AMAZON.CAON
# 11  AMZN Mktp CA*4L5L22N53 WWW.AMAZON.CAON
# 12                 WINNERS 474 MONTREAL QC
# 13                   ADONIS ANJOU ANJOU QC
# 14                    FOODHERO MONTREAL QC
# 15                   IGA #8168 MONTREAL QC
# 16  AMZN Mktp CA*NQ5PS64O3 WWW.AMAZON.CAON
# 17            SAQ23199 SAQ.COM MONTREAL QC
# 18          TOMATE BASILIC POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005    5.00 2023-02-10  2023-02-10
# 4         0.005   64.32 2023-02-10  2023-02-10
# 5         0.005   26.03 2023-02-10  2023-02-10
# 6         0.005   57.20 2023-02-10  2023-02-10
# 7         0.005    6.88 2023-02-10  2023-02-13
# 8         0.020   38.00 2023-02-11  2023-02-13
# 9         0.005    4.75 2023-02-11  2023-02-13
# 10        0.020  100.49 2023-02-11  2023-02-13
# 11        0.005   12.26 2023-02-12  2023-02-13
# 12        0.005   16.65 2023-02-12  2023-02-13
# 13        0.005   15.26 2023-02-12  2023-02-13
# 14        0.000    8.79 2023-02-12  2023-02-13
# 15        0.020  192.38 2023-02-16  2023-02-16
# 16        0.005    3.88 2023-02-18  2023-02-20
# 17        0.005   55.69 2023-02-18  2023-02-20
# 18        0.005   13.37 2023-02-19  2023-02-20
# 19        0.005   26.33 2023-02-20  2023-02-20
# 20        0.005   41.37 2023-02-20  2023-02-20
# 21        0.005  984.81 2023-02-20  2023-02-21
# 22        0.005  984.81 2023-02-20  2023-02-21
# 23        0.005  617.37 2023-02-21  2023-02-21
# 24        0.020   10.00 2023-02-23  2023-02-23
# 25        0.020   10.00 2023-02-23  2023-02-23
#
#                                   merchant
# 3                     FLASHFOOD TORONTO ON
# 4         SUPER C PAT 5963 POINTE AUX TRQC
# 5             MAXI #8987 * POINTE-AUX-TRQC
# 6                 LE BLIND PIG MONTREAL QC
# 7    MAGASIN CDN TIRE #00009 ST LEONARD QC
# 8           DEFI DANIEL LEQUIN JOLIETTE QC
# 9     AGENCE DE MOBILITE DURABLMONTREAL QC
# 10                     PULLMAN MONTREAL QC
# 11                    FOODHERO MONTREAL QC
# 12   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 13                   IGA #8168 MONTREAL QC
# 14                   IGA #8168 MONTREAL QC
# 15          TOMATE BASILIC POINTE-AUX-TRQC
# 16            MAXI #8987 * POINTE-AUX-TRQC
# 17        SUPER C PAT 5963 POINTE AUX TRQC
# 18  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 19        SUPER C REPENTIGNY REPENTIGNY QC
# 20     H&M CA #087- GALERIES REPENTIGNY QC
# 21   AIR CAN* 0141116598585AIRCANADA.COMMB
# 22   AIR CAN* 0141116598586AIRCANADA.COMMB
# 23    EXPEDIA 72495655094635 EXPEDIA.CA ON
# 24       LE CIRCUIT ELECTRIQUE MONTREAL QC
# 25       LE CIRCUIT ELECTRIQUE MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   18.15 2023-03-23  2023-03-24
# 4         0.020    3.50 2023-03-23  2023-03-24
# 5         0.020    3.50 2023-03-25  2023-03-27
# 6         0.005   70.24 2023-03-25  2023-03-27
# 7         0.005   26.60 2023-03-25  2023-03-27
# 8         0.005    6.98 2023-03-27  2023-03-27
# 9         0.005    6.94 2023-03-27  2023-03-27
# 10        0.005   13.73 2023-03-27  2023-03-27
# 11        0.005    6.99 2023-03-27  2023-03-28
# 12        0.005    7.98 2023-03-28  2023-03-28
# 13        0.020   72.72 2023-03-30  2023-03-30
# 14        0.005   22.54 2023-03-30  2023-03-30
# 15        0.005   82.21 2023-03-30  2023-03-30
# 16        0.005    6.74 2023-03-31  2023-03-31
# 17        0.020    9.98 2023-04-05  2023-04-05
#
#                                   merchant
# 3    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 4      STM HONORE BEAUG DIN101 MONTREAL QC
# 5      STM HONORE BEAUG DIN101 MONTREAL QC
# 6         SUPER C PAT 5963 POINTE AUX TRQC
# 7    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 8   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 9         SUPER C PAT 5963 POINTE AUX TRQC
# 10            MAXI #8987 * POINTE-AUX-TRQC
# 11                   IGA #8168 MONTREAL QC
# 12  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 13               SUSHISAMA POINTE-AUX-TRQC
# 14        SUPER C PAT 5963 POINTE AUX TRQC
# 15            MAXI #8987 * POINTE-AUX-TRQC
# 16  METRO BOUCHER JEAN MAT SAINT JEAN DEQC
# 17                   BISTROT INT DORVAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   87.79 2023-04-06  2023-04-06
# 5         0.005   54.10 2023-04-06  2023-04-06
# 7         0.005   13.31 2023-04-06  2023-04-06
# 9         0.005   48.46 2023-04-07  2023-04-10
# 11        0.005   27.70 2023-04-07  2023-04-11
# 13        0.005  139.12 2023-04-10  2023-04-11
# 15        0.005    6.63 2023-04-12  2023-04-12
# 16        0.005   29.25 2023-04-13  2023-04-14
# 17        0.005   11.52 2023-04-14  2023-04-14
# 18        0.005   64.84 2023-04-14  2023-04-14
# 19        0.005   22.77 2023-04-14  2023-04-14
# 20        0.005   68.40 2023-04-14  2023-04-14
# 21        0.020    3.75 2023-04-15  2023-04-17
# 22        0.005   15.65 2023-04-15  2023-04-17
# 23        0.005    3.99 2023-04-16  2023-04-17
# 24        0.005   35.05 2023-04-16  2023-04-17
# 25        0.005    1.48 2023-04-17  2023-04-17
# 26        0.005    5.23 2023-04-20  2023-04-20
# 27        0.005   16.95 2023-04-20  2023-04-21
# 28        0.005   18.30 2023-04-21  2023-04-21
# 29        0.005    2.86 2023-04-22  2023-04-24
# 30        0.005   48.72 2023-04-23  2023-04-24
# 31        0.020   23.70 2023-04-23  2023-04-24
#
#                                   merchant
# 3            RUBY'S GENERAL STORE BRYCE UT
# 5       SHELL OIL10007497018 CEDAR CITY UT
# 7          BRYCE CANYON NATURAL H BRYCE UT
# 9         ZION NATIONAL PARK SPRINGDALE UT
# 11        TOWN OF SPRINGDALE SPRINGDALE UT
# 13    2300 SAHARA HOTEL OPERA LAS VEGAS NV
# 15            MAXI #8987 * POINTE-AUX-TRQC
# 16   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18        SUPER C PAT 5963 POINTE AUX TRQC
# 19            MAXI #8987 * POINTE-AUX-TRQC
# 20   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 21         CAPULUS CAFE MOBILE MONTREAL QC
# 22      SAQ23064 SHERBROOKE ES MONTREAL QC
# 23        SUPER C PAT 5963 POINTE AUX TRQC
# 24   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 25          APPLE.COM/BILL 866-712-7753 ON
# 26            MAXI #8987 * POINTE-AUX-TRQC
# 27   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 28   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 29            MAXI #8987 * POINTE-AUX-TRQC
# 30  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 31   SOCIETE DES TRAVERSIER SOREL-TRACY QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   17.75 2023-08-24  2023-08-24
# 4         0.005   24.81 2023-08-24  2023-08-24
# 5         0.005   19.69 2023-08-24  2023-08-24
# 6         0.005   10.00 2023-08-24  2023-08-25
# 7         0.005   23.73 2023-08-24  2023-08-25
# 8         0.005   21.83 2023-08-25  2023-08-25
# 9         0.005   11.27 2023-08-25  2023-08-25
# 10        0.005  264.42 2023-08-27  2023-08-28
# 11        0.005   28.31 2023-08-27  2023-08-28
# 12        0.005    9.83 2023-08-27  2023-08-28
# 13        0.000   39.52 2023-08-27  2023-08-28
# 14        0.005   10.32 2023-08-28  2023-08-28
# 15        0.000   66.00 2023-08-28  2023-08-28
# 16        0.000   21.83 2023-08-28  2023-08-28
# 17        0.005   45.98 2023-08-29  2023-08-30
# 18        0.005   68.03 2023-08-30  2023-08-30
#
#                                    merchant
# 3                      FOODHERO MONTREAL QC
# 4    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 5          SUPER C PAT 5963 POINTE AUX TRQC
# 6                     IGA #8168 MONTREAL QC
# 7                   MAXI #8622 LACHENAIE QC
# 8    AMZN Mktp CA*T35OE2JH2 WWW.AMAZON.CAON
# 9                MAXI #8987 POINTE-AUX-TRQC
# 10       SP CANADA VALISE DEP ST-LAURENT QC
# 11       QUEBECLOISIRS PLACE VE MONTREAL QC
# 12              ADONIS 21943 ANJOU ANJOU QC
# 13                  RW & CO. #2216 ANJOU QC
# 14   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15     NBX*CENTRECOMROUSSIN POINTE-AUX-TRQC
# 16   AMZ*PremiumpartsWhosal WWW.AMAZON.CAON
# 17  WOLVERINE WORLDWIDE CANADMISSISSAUGA ON
# 18    INSCRIPTIONENLIGNE.CA SAINT-EUSTACHQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   28.74 2023-08-31  2023-08-31
# 4         0.005    7.37 2023-09-01  2023-09-01
# 5         0.005   20.00 2023-09-03  2023-09-05
# 6         0.020    6.89 2023-09-03  2023-09-05
# 7         0.005   25.00 2023-09-03  2023-09-05
# 8         0.005   53.72 2023-09-04  2023-09-05
# 9         0.005   39.05 2023-09-04  2023-09-05
# 10        0.000   53.72 2023-09-04  2023-09-05
# 11        0.000   10.33 2023-09-04  2023-09-05
# 12        0.005  886.32 2023-09-05  2023-09-05
# 13        0.005  886.32 2023-09-05  2023-09-05
# 14        0.005  781.32 2023-09-05  2023-09-05
# 15        0.020   57.00 2023-09-08  2023-09-08
# 16        0.005   17.30 2023-09-10  2023-09-11
# 17        0.000    3.64 2023-09-11  2023-09-11
# 18        0.005    9.18 2023-09-12  2023-09-12
# 19        0.005   87.34 2023-09-14  2023-09-14
# 20        0.005    7.60 2023-09-15  2023-09-15
# 21        0.005  131.84 2023-09-16  2023-09-18
# 22        0.005    1.48 2023-09-17  2023-09-18
# 23        0.005   51.48 2023-09-19  2023-09-19
# 24        0.005   36.44 2023-09-19  2023-09-19
# 25        0.005   48.23 2023-09-21  2023-09-21
# 26        0.005   68.99 2023-09-21  2023-09-21
# 27        0.005   49.38 2023-09-22  2023-09-22
# 28        0.020   41.51 2023-09-22  2023-09-22
# 29        0.020   32.40 2023-09-23  2023-09-25
# 30        0.020   29.08 2023-09-23  2023-09-25
#
#                                   merchant
# 3       UNARBREPOURMONQUARTIER MONTREAL QC
# 4   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 5    SQ *FERME LA VRAIE VIE Saint-Zenon QC
# 6              NETFLIX.COM 866-716-0414 ON
# 7      SQ *MIEL MORAND INC. Saint-Zenon QC
# 8        LIBRAIRIE RENAUD BRAY MONTREAL QC
# 9        LIBRAIRIE RENAUD BRAY MONTREAL QC
# 10       LIBRAIRIE RENAUD BRAY MONTREAL QC
# 11       LIBRAIRIE RENAUD BRAY MONTREAL QC
# 12            RAM 1479652367226MONTREAL QC
# 13            RAM 1479652367225MONTREAL QC
# 14            RAM 1479652367222MONTREAL QC
# 15        CAFE LES FRAICHES LASSOMPTION QC
# 16                    FOODHERO MONTREAL QC
# 17                    FOODHERO MONTREAL QC
# 18          JEAN COUTU 045 POINTE AUX TRQC
# 19  AMZN Mktp CA*TX9DD0OD0 WWW.AMAZON.CAON
# 20    AGENCE DE MOBILITE DURABLMONTREAL QC
# 21                 SAQ.COM/12424 QUEBEC QC
# 22          APPLE.COM/BILL 866-712-7753 ON
# 23  AMZN Mktp CA*TX0II8Z91 WWW.AMAZON.CAON
# 24                    FOODHERO MONTREAL QC
# 25  AMZN Mktp CA*TX9JK69D0 WWW.AMAZON.CAON
# 26      TUANGO INC/#LD-0068960 MONTREAL QC
# 27  AMZN Mktp CA*T188C8AS2 WWW.AMAZON.CAON
# 28              3 BRASSEURS ANJOU ANJOU QC
# 29            PUB LORD WILLIAM MONTREAL QC
# 30                BUVETTE JUNE MONTREAL QC

# %%
for t in t_list:
    t.save()

# %%
cat = Budget.objects.all()
for c in cat:
    print(c.spending_item_name)
# Out:
# Activité Enfants
# Allocation canadienne pour enfants
# Allocation famille QC
# Apple iCloud
# assurances
# BS
# Cadeau
# Cheveux
# CLub TRI PAT
# Course Geneviève
# epicerie
# Estheticienne
# frais de garde
# Frais scholaires
# Hydro
# Hypothèque
# Immatriculations
# imprévues
# Internet
# Les Fraiches
# Massage
# Massages
# Netflix
# Nourriture Cochons
# Paye
# Permis de conduire
# Pharmacie
# pneus
# Remboursement d'impôt
# Restaurant
# Suppl. fournitures scolaires
# Taxe municipales
# Taxe scholaire
# Transport (electricité / parking / metro-bus)
# Vetement Enfants
# Vetement Genevieve
# vie sociale
# vin
# voiture 50000 dans 5 ans
# Voyages

# %%
# t_list = VisaDesjardinsTransaction.objects.all()
t_list = []
for pdf in pdf_to_uplaod:
    file = os.path.join(folder_path, pdf)
    vd = VisaDesjardinsPdfTransactionProcessor(file, user)
    t_list += vd.get_transaction_list()
    
merch = Merchant.objects.all()
merch_name_list = [m.name for m in merch]

alchool_list = ["NORMAN HARDIE WINERY", "SAQ", "KARLO ESTATES", "LCBO", "PARSONS BREWING", "STOCK AND ROW", "HINTERLAND WINE",
                "COUNTY CIDER PICTON", "SLAKE BREWING PICTON", 'DOMAINE DARIUS HILLIER ON', 'CLOSSON CHASE VINEYARD HILLIER ON',
                "REDTAIL VINEYARD", "ROSEHALL RUN VINEYARDS", "AUX P'TITS BOCAUX"]
budget_item_alchool = Budget.objects.get(id=819)
epicerie_liste = ["SUPER C", "METRO", "MAXI", "IGA", "FOODHERO", "LES FRAICHES", 
                  "ADONIS", "PROVIGO", "MARCHE RICHELIEU", 'MIEL MORAND',
                  'FERME LA VRAIE VIE', "PASTA AND FUMO", "FLASHFOOD", "CAPULUS CAFE MOBILE",
                  "MONSIEUR COCKTAIL", "Nespresso Canada"]
budget_category_epicerie = Budget.objects.get(id=809)
pharmacie_liste = ["PHARMACIE", "JEAN COUTU", "BRUNET", "PHARMAPRIX", "PROXI"]
budget_category_pharmacie = Budget.objects.get(id=816)
transport_liste = ["AGENCE DE MOBILITE DURABLMONTREAL", "STM", "LE CIRCUIT ELECTRIQUE MONTREAL",
                   "FLO SERVICES QUEBEC", 'ESSO', "SHELL", "PETRO CANADA"]
budget_category_transport = Budget.objects.get(id=828)
linge_gen_liste = ["RW & CO", "WINNERS", "OLDNAVY.COM", "RW", "REITMANS", 
                   "SIMONS", "H&M", "MONTELLE INTIMATE", "GLOBO", "WOLVERINE WORLDWIDE", "ETSY", "COBIEBOUTIQUE"]
budget_category_linge_gen = Budget.objects.get(id=815)
restaurant_liste = ['LES ENFANTS TERRIBLES', 'PETIT QUEBEC REPENTIGNY', 'MICROBRASSERIE COATICOOK COATICOOK',
                    'PUB LORD WILLIAM', 'SMOKING BBQ MONTREAL', "L'OEUFRIER BROMONT",
                    'DUNNS FAMOUS', "L'HELICOPTERE", "RESTO INDIAN", "PULLMAN", 'BUVETTE JUNE',
                    "LE POKE STATION", "SUSHISAMA", "MICROBRASSERIE LA MEMPH", "MCDONALD'S", "ERABLIERE",
                    "POKE STATION", "LE DATE", "BOULEVARD CLERMONT", "HENRI BRASSERIE FRANCA"
                   ]
budget_category_restaurant = Budget.objects.get(id=817)
voyage_liste = ["AIRBNB", "CITY OF KINGSTON", "SEPAQ", "RAM", "DVERT", "SERVICE CANADA"
                'EXPEDIA', 'AIR CAN', 'BRYCE CANYON', 'ZION NATIONAL', 'SPRINGDALE', 'LAS VEGAS',
                "EXPEDIA.CA", "RUBY'S GENERAL"
               ]
budget_category_voyage = Budget.objects.get(id=820)
cadeau_list = ['JULES & HENRI', 'LIBRAIRIE RENAUD BRAY', 'QUEBECLOISIRS', 'CANADA VALISE', 'LIBRAIRE', 'HORIZON ROC', 'Billabong']
budget_category_cadeau = Budget.objects.get(id=822)
activite_enfants_list = ['CENTRECOMROUSSIN', 'INSCRIPTIONENLIGNE.CA']
budget_category_activite_enfants = Budget.objects.get(id=827)
activite_equipement_sport_gen_list = ['RACEROSTER PRISON', 'SP YUL RUN']
budget_category_equipement_sport_gen = Budget.objects.get(id=854)

merchat_name_list = [alchool_list 
                     ,epicerie_liste 
                     ,pharmacie_liste 
                     ,transport_liste 
                     ,linge_gen_liste 
                     ,restaurant_liste 
                     ,voyage_liste 
                     ,cadeau_list 
                     ,activite_enfants_list 
                     ,activite_equipement_sport_gen_list
                    ]
budget_category_list = [budget_item_alchool, 
                        budget_category_epicerie, 
                        budget_category_pharmacie, 
                        budget_category_transport, 
                        budget_category_linge_gen, 
                        budget_category_restaurant, 
                        budget_category_voyage, 
                        budget_category_cadeau, 
                        budget_category_activite_enfants, 
                        budget_category_equipement_sport_gen
                       ]

    
from django.db.models import Q
# Using Q objects for complex OR conditions
for term_list, budget_category in zip(merchat_name_list, budget_category_list):
    query = Q()
    for term in term_list:
        query |= Q(merchant__contains=term)
        for t in t_list.filter(query):
            print(t.merchant, t.amount)
# Out:
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   25.55 2023-04-25  2023-04-25
# 4         0.005   41.39 2023-04-25  2023-04-25
# 5         0.005   16.95 2023-04-25  2023-04-26
# 6         0.020  107.63 2023-04-28  2023-04-28
# 7         0.005   44.45 2023-04-29  2023-05-01
# 8         0.005   24.67 2023-04-29  2023-05-01
# 9         0.005   17.76 2023-04-29  2023-05-01
# 10        0.005   29.33 2023-04-29  2023-05-01
# 11        0.005   23.54 2023-04-29  2023-05-01
# 12        0.000   14.36 2023-04-29  2023-05-01
# 13        0.005    4.59 2023-05-01  2023-05-01
# 14        0.005    4.99 2023-05-02  2023-05-02
# 15        0.005   78.60 2023-05-04  2023-05-04
# 16        0.005   31.09 2023-05-04  2023-05-04
# 17        0.005   24.57 2023-05-05  2023-05-05
# 18        0.005   14.50 2023-05-06  2023-05-08
#
#                                   merchant
# 3         SUPER C PAT 5963 POINTE AUX TRQC
# 4             MAXI #8987 * POINTE-AUX-TRQC
# 5    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 6        ALLO MON COCO PAT PTE AUX TREMBQC
# 7      SAQ23106CARREFOUR DE LA MONTREAL QC
# 8               BRUNET PLUS ANJOU ANJOU QC
# 9   MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC
# 10             ADONIS 21943 ANJOU ANJOU QC
# 11        SUPER C PAT 5963 POINTE AUX TRQC
# 12              BRUNET PLUS ANJOU ANJOU QC
# 13            MAXI #8987 * POINTE-AUX-TRQC
# 14  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15     SAQ23106CARREFOUR DE LA MONTREAL QC
# 16        SUPER C PAT 5963 POINTE AUX TRQC
# 17  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18     MAXI & CIE REPENTIGNY REPENTIGNY QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   40.28 2023-05-07  2023-05-08
# 4         0.005    7.99 2023-05-07  2023-05-08
# 5         0.005  114.34 2023-05-08  2023-05-08
# 6         0.005    7.98 2023-05-08  2023-05-08
# 7         0.005   37.00 2023-05-10  2023-05-10
# 8         0.005   15.95 2023-05-10  2023-05-10
# 9         0.005   12.33 2023-05-10  2023-05-11
# 10        0.020   19.84 2023-05-10  2023-05-11
# 11        0.005  211.82 2023-05-10  2023-05-12
# 12        0.020   10.86 2023-05-11  2023-05-11
# 13        0.005   21.16 2023-05-13  2023-05-15
# 14        0.005    5.96 2023-05-13  2023-05-15
# 15        0.005    4.99 2023-05-13  2023-05-15
# 16        0.020   55.00 2023-05-14  2023-05-15
# 17        0.005    8.98 2023-05-14  2023-05-15
# 18        0.005   15.95 2023-05-14  2023-05-15
# 19        0.005   16.65 2023-05-15  2023-05-15
# 20        0.005   69.27 2023-05-15  2023-05-15
# 21        0.005   49.25 2023-05-17  2023-05-17
# 22        0.005    1.48 2023-05-17  2023-05-17
# 23        0.005   15.55 2023-05-18  2023-05-18
# 24        0.020   50.24 2023-05-18  2023-05-19
# 25        0.005   30.53 2023-05-19  2023-05-19
# 26        0.005   71.07 2023-05-19  2023-05-19
# 27        0.005    9.52 2023-05-19  2023-05-19
# 28        0.005   69.65 2023-05-19  2023-05-19
# 29        0.020   72.07 2023-05-21  2023-05-23
# 30        0.005  284.78 2023-05-22  2023-05-23
# 31        0.020   20.77 2023-05-22  2023-05-23
# 32        0.005    1.40 2023-05-22  2023-05-23
# 33        0.020   25.30 2023-05-24  2023-05-24
#
#                                     merchant
# 3                 METRO BEAUBIEN MONTREAL QC
# 4                IGA EXTRA 259 ST-LEONARD QC
# 5           SP MONTELLE INTIMATE MONTREAL QC
# 6           SUPER C PAT 5963 POINTE AUX TRQC
# 7        SAQ23106CARREFOUR DE LA MONTREAL QC
# 8        SAQ23106CARREFOUR DE LA MONTREAL QC
# 9                      IGA #8168 MONTREAL QC
# 10                 LE LOUNGE SAINT-SAUVEURQC
# 11       MANOIR SAINT SAUVEUR 450-2271811 QC
# 12       ST-SAU PUB GOURMAND SAINT-SAUVEURQC
# 13              SP JULES & HENRI MONTREAL QC
# 14  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 15    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 16          CAFE LES FRAICHES LASSOMPTION QC
# 17       MAXI & CIE REPENTIGNY REPENTIGNY QC
# 18         SAQ23070 REPENTIGNY REPENTIGNY QC
# 19    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 20          SUPER C PAT 5963 POINTE AUX TRQC
# 21       SAQ23106CARREFOUR DE LA MONTREAL QC
# 22            APPLE.COM/BILL 866-712-7753 ON
# 23       SAQ23106CARREFOUR DE LA MONTREAL QC
# 24          LES INSULAIRES MICROBRA LAVAL QC
# 25    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 26          SUPER C PAT 5963 POINTE AUX TRQC
# 27                  MAXI #8622 TERREBONNE QC
# 28                      SAQ23004 BROSSARD QC
# 29          MICROBRASSERIE LA MEMPH MAGOG QC
# 30                      RW #2499 MONTREAL QC
# 31     MCDONALD'S #18127 QPS ANGE-GARDIEN QC
# 32      AGENCE DE MOBILITE DURABLMONTREAL QC
# 33           LE POKE STATION PAT MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.020    3.50 2023-06-26  2023-06-27
# 4         0.020   79.34 2023-06-27  2023-06-28
# 5         0.020   68.76 2023-06-29  2023-06-29
# 6         0.005   68.77 2023-06-30  2023-06-30
# 7         0.005   17.33 2023-06-30  2023-06-30
# 8         0.005    5.46 2023-06-30  2023-06-30
# 9         0.005    8.26 2023-07-02  2023-07-04
# 10        0.005   24.14 2023-07-02  2023-07-04
# 11        0.005   10.11 2023-07-02  2023-07-04
# 12        0.005   26.95 2023-07-02  2023-07-04
# 13        0.005    6.27 2023-07-04  2023-07-04
# 14        0.005  344.37 2023-07-06  2023-07-06
# 15        0.005  446.69 2023-07-06  2023-07-06
# 16        0.005   24.72 2023-07-06  2023-07-07
# 17        0.005   37.81 2023-07-07  2023-07-07
# 18        0.005   14.70 2023-07-07  2023-07-07
#
#                                     merchant
# 3             STM LAURIER DIN101 MONTREAL QC
# 4                      CANAILLES MONTREAL QC
# 5         GASTON RESTAURANT APPO MONTREAL QC
# 6           SUPER C PAT 5963 POINTE AUX TRQC
# 7       PHARMACIE VINH THE JIMMY MONTREAL QC
# 8           CHEZ BAPTISTE MASSON MONTREAL QC
# 9   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 10             DOLLARAMA # 285 REPENTIGNY QC
# 11              JEAN COUTU 046 REPENTIGNY QC
# 12              MAXI #8987 * POINTE-AUX-TRQC
# 13    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 14          OLDNAVY.COM 2944 505-462-0076 ON
# 15         AIRBNB * HMT2PREXQ8 AIRBNB.COM GB
# 16                     IGA #8168 MONTREAL QC
# 17    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18              MAXI #8987 * POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   60.53 2023-07-07  2023-07-07
# 4         0.005    8.05 2023-07-07  2023-07-07
# 5         0.020   20.00 2023-07-08  2023-07-10
# 6         0.005  149.46 2023-07-08  2023-07-10
# 7         0.005  122.60 2023-07-09  2023-07-10
# ..          ...     ...        ...         ...
# 60        0.005   11.28 2023-07-22  2023-07-24
# 61        0.005   10.75 2023-07-23  2023-07-24
# 62        0.005   22.30 2023-07-23  2023-07-24
# 63        0.005   13.23 2023-07-23  2023-07-24
# 64        0.005   29.85 2023-07-23  2023-07-24
#
#                                   merchant
# 3         SUPER C PAT 5963 POINTE AUX TRQC
# 4                    IGA #8168 MONTREAL QC
# 5        LE CIRCUIT ELECTRIQUE MONTREAL QC
# 6             #414 SPORTS EXPERTS ANJOU QC
# 7              Nespresso Canada Toronto ON
# ..                                     ...
# 60  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 61            SEPAQ YAMASKA ROXTON POND QC
# 62            SEPAQ YAMASKA ROXTON POND QC
# 63            SEPAQ YAMASKA ROXTON POND QC
# 64          SEPAQ 1 800 665 6527 QUEBEC QC
#
# [62 rows x 5 columns]
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   19.10 2023-07-23  2023-07-24
# 4         0.005   35.11 2023-07-23  2023-07-24
# 5         0.005   18.15 2023-07-23  2023-07-24
# 6         0.005   12.96 2023-07-24  2023-07-24
# 7         0.005   29.90 2023-07-24  2023-07-25
# 8         0.005   40.17 2023-07-25  2023-07-25
# 9         0.005   48.30 2023-07-26  2023-07-26
# 10        0.005  186.64 2023-07-26  2023-07-26
# 11        0.005    6.79 2023-07-26  2023-07-26
#
#                               merchant
# 3          SEPAQ 1 800 665 6527 QUEBEC
# 4            METRO PLOUFFE MAGOG MAGOG
# 5                 SAQ23082 MAGOG MAGOG
# 6            METRO PLOUFFE MAGOG MAGOG
# 7                 SAQ23082 MAGOG MAGOG
# 8   MICROBRASSERIE COATICOOK COATICOOK
# 9                          DVERT MAGOG
# 10             REITMANS #1499 MONTREAL
# 11           METRO PLOUFFE MAGOG MAGOG
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005  181.54 2023-09-28  2023-09-28
# 4         0.005   50.53 2023-09-28  2023-09-28
# 5         0.005    5.29 2023-09-30  2023-10-02
# 6         0.020   68.30 2023-10-02  2023-10-02
# 7         0.020    2.42 2023-10-02  2023-10-02
# 8         0.020    6.89 2023-10-03  2023-10-03
# 9         0.005   79.18 2023-10-03  2023-10-03
# 10        0.005   30.19 2023-10-04  2023-10-04
# 11        0.005  138.68 2023-10-04  2023-10-05
# 12        0.020   16.03 2023-10-07  2023-10-10
# 13        0.005   35.00 2023-10-08  2023-10-10
# 14        0.020   57.00 2023-10-08  2023-10-10
# 15        0.020    5.25 2023-10-08  2023-10-10
# 16        0.020   18.84 2023-10-09  2023-10-10
# 17        0.005  122.14 2023-10-11  2023-10-11
# 18        0.005    1.48 2023-10-17  2023-10-17
#
#                                     merchant
# 3     AMZN Mktp CA*T16F392L0 WWW.AMAZON.CAON
# 4     AMZN Mktp CA*T10UZ0KR0 WWW.AMAZON.CAON
# 5   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 6            LE POKE STATION PAT MONTREAL QC
# 7              TIM HORTONS #1151 MONTREAL QC
# 8                NETFLIX.COM 866-716-0414 ON
# 9     AMZN Mktp CA*T98OL3ZE1 WWW.AMAZON.CAON
# 10                      FOODHERO MONTREAL QC
# 11                   SAQ.COM/12424 QUEBEC QC
# 12                     LA STATION EASTMAN QC
# 13                PERFECTION.CA LONGUEUIL QC
# 14          CAFE LES FRAICHES LASSOMPTION QC
# 15                   PASTA AND FUMO MAGOG QC
# 16                 LA MIE D'ORFORD ORFORD QC
# 17    GLOBO CANADA- E-COMMER SAINT- LAURENQC
# 18            APPLE.COM/BILL 866-712-7753 ON
#    BONIDOLLARS  amount       date record_date  \
# 3        0.005  114.00 2023-10-19  2023-10-19
# 4        0.005   20.98 2023-10-25  2023-10-25
# 5        0.005   45.70 2023-10-25  2023-10-25
#
#                                    merchant
# 3  SERVICE CANADA PT AUX TR PT AUX TREMB QC
# 4                      FOODHERO MONTREAL QC
# 5                   COBIEBOUTIQUE LONDON GB
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   57.23 2023-05-25  2023-05-25
# 4         0.005   16.95 2023-05-26  2023-05-26
# 5         0.005   49.45 2023-05-27  2023-05-29
# 6         0.020    9.00 2023-05-27  2023-05-29
# 7         0.005   41.49 2023-05-27  2023-05-29
# 8         0.000  101.04 2023-05-27  2023-05-29
# 9         0.005   11.47 2023-05-31  2023-05-31
# 10        0.005   29.60 2023-05-31  2023-06-01
# 11        0.005    7.38 2023-06-01  2023-06-01
# 12        0.020   25.43 2023-06-01  2023-06-01
# 13        0.020   10.58 2023-06-01  2023-06-01
# 14        0.005   14.08 2023-06-01  2023-06-01
# 15        0.020   15.00 2023-06-01  2023-06-02
# 16        0.005   34.44 2023-06-02  2023-06-02
# 17        0.020   13.55 2023-06-02  2023-06-02
# 18        0.005   17.95 2023-06-03  2023-06-05
#
#                                  merchant
# 3        SUPER C PAT 5963 POINTE AUX TRQC
# 4     SAQ23106CARREFOUR DE LA MONTREAL QC
# 5     SAQ23106CARREFOUR DE LA MONTREAL QC
# 6    SQ *LA BUVETTE DU QUAI PAMontreal QC
# 7        SUPER C PAT 5963 POINTE AUX TRQC
# 8                 RW & CO. #2216 ANJOU QC
# 9            MAXI #8987 * POINTE-AUX-TRQC
# 10      SAQ23327 REPENTIGNY REPENTIGNY QC
# 11            SHELL C81389 CHARLEMAGNE QC
# 12            LES TROIS GARCONS QUEBEC QC
# 13            LES TROIS GARCONS QUEBEC QC
# 14             MARCHE RICHELIEU QUEBEC QC
# 15  STARBUCKS COFFEE # 599 CHARLEMAGNE QC
# 16     LA MAISON SIMONS INC(QUE)QUEBEC QC
# 17               PUB ST-PATRICK QUEBEC QC
# 18    SAQ23106CARREFOUR DE LA MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005    4.60 2023-06-03  2023-06-05
# 4         0.005  144.82 2023-06-03  2023-06-05
# 5         0.005    6.31 2023-06-03  2023-06-05
# 6         0.020   13.89 2023-06-03  2023-06-05
# 7         0.020  133.21 2023-06-04  2023-06-05
# 9         0.005   67.40 2023-06-04  2023-06-05
# 10        0.005   12.81 2023-06-04  2023-06-05
# 11        0.005   30.53 2023-06-04  2023-06-05
# 12        0.005   25.83 2023-06-04  2023-06-05
# 13        0.005   20.68 2023-06-05  2023-06-05
# 14        0.005   33.22 2023-06-05  2023-06-05
# 15        0.005    8.94 2023-06-05  2023-06-05
# 16        0.000  126.28 2023-06-06  2023-06-06
# 18        0.005   40.22 2023-06-07  2023-06-07
# 19        0.005   24.10 2023-06-08  2023-06-08
# 20        0.005    8.48 2023-06-08  2023-06-08
# 21        0.005   16.95 2023-06-09  2023-06-09
# 22        0.005   21.28 2023-06-09  2023-06-09
# 23        0.005   49.86 2023-06-09  2023-06-09
# 24        0.005   11.17 2023-06-09  2023-06-09
# 25        0.005   57.48 2023-06-10  2023-06-12
# 26        0.005   30.55 2023-06-10  2023-06-12
# 27        0.020   15.23 2023-06-10  2023-06-12
# 28        0.020   13.00 2023-06-10  2023-06-12
# 29        0.005   24.38 2023-06-11  2023-06-12
# 30        0.005   11.27 2023-06-11  2023-06-12
# 31        0.005    5.99 2023-06-11  2023-06-12
# 32        0.005   10.18 2023-06-12  2023-06-13
# 33        0.005   59.70 2023-06-13  2023-06-13
# 34        0.005    4.04 2023-06-14  2023-06-14
# 35        0.005   18.15 2023-06-15  2023-06-15
# 36        0.005   18.16 2023-06-15  2023-06-15
# 37        0.005   18.84 2023-06-15  2023-06-16
# 38        0.005   10.00 2023-06-15  2023-06-16
# 39        0.020   60.61 2023-06-15  2023-06-16
# 40        0.005   20.76 2023-06-15  2023-06-16
# 41        0.020   28.98 2023-06-16  2023-06-16
# 42        0.005    5.29 2023-06-16  2023-06-16
# 43        0.005    2.99 2023-06-16  2023-06-16
# 44        0.005    4.07 2023-06-16  2023-06-16
# 45        0.005   58.10 2023-06-16  2023-06-16
# 46        0.005    1.48 2023-06-17  2023-06-19
# 47        0.005  235.85 2023-06-17  2023-06-19
# 48        0.005    3.44 2023-06-19  2023-06-19
# 49        0.005    7.99 2023-06-19  2023-06-19
# 50        0.005   15.42 2023-06-19  2023-06-19
# 51        0.005   59.59 2023-06-19  2023-06-19
# 52        0.005   54.46 2023-06-19  2023-06-19
# 53        0.005    5.00 2023-06-20  2023-06-20
# 54        0.005   13.96 2023-06-20  2023-06-20
# 55        0.000   37.96 2023-06-20  2023-06-20
# 56        0.005   10.11 2023-06-20  2023-06-21
# 57        0.005   98.20 2023-06-22  2023-06-22
# 58        0.005   24.67 2023-06-22  2023-06-22
# 59        0.005    5.26 2023-06-22  2023-06-23
#
#                                   merchant
# 3          DOLLARAMA #1362 POINTE-AUX-TRQC
# 4       TUANGO INC/#LD-0063868 MONTREAL QC
# 5     PHARMACIE VINH THE JIMMY MONTREAL QC
# 6           MCDONALD'S #11258 DONNACONA QC
# 7               Prezi, Inc. 415-4948313 CA
# 9      SAQ23106CARREFOUR DE LA MONTREAL QC
# 10  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11        SUPER C PAT 5963 POINTE AUX TRQC
# 12                   IGA #8168 MONTREAL QC
# 13  AMZN Mktp CA*VW5AP2J43 WWW.AMAZON.CAON
# 14  AMZN Mktp CA*156UA1NW3 WWW.AMAZON.CAON
# 15             ADONIS 21943 ANJOU ANJOU QC
# 16              Prezi, Inc. 415-4948313 CA
# 18  AMZN Mktp CA*CR18X5CT3 WWW.AMAZON.CAON
# 19        Amazon.ca*KP8828J23 AMAZON.CA ON
# 20  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 21     SAQ23106CARREFOUR DE LA MONTREAL QC
# 22            MAXI #8987 * POINTE-AUX-TRQC
# 23        SUPER C PAT 5963 POINTE AUX TRQC
# 24            MAXI #8987 * POINTE-AUX-TRQC
# 25                 WINNERS 474 MONTREAL QC
# 26     SAQ23106CARREFOUR DE LA MONTREAL QC
# 27                 SMOKING BBQ MONTREAL QC
# 28     STM LOGE LANGELIER N101 MONTREAL QC
# 29                    FOODHERO MONTREAL QC
# 30       AUX P'TITS BOCAUX POINTE AUX TRQC
# 31                   IGA #8168 MONTREAL QC
# 32                   IGA #8168 MONTREAL QC
# 33     SAQ23011 HALLES D'ANJOU MONTREAL QC
# 34            MAXI #8987 * POINTE-AUX-TRQC
# 35     SAQ23106CARREFOUR DE LA MONTREAL QC
# 36        SUPER C PAT 5963 POINTE AUX TRQC
# 37                   IGA #8168 MONTREAL QC
# 38    AGENCE DE MOBILITE DURABLMONTREAL QC
# 39               PETITE MARCHE MONTREAL QC
# 40  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 41                    CAFE ISO MONTREAL QC
# 42            LA MARCHE A COTE Montreal QC
# 43            METRO PLOUFFE MAGOG MAGOG QC
# 44    AGENCE DE MOBILITE DURABLMONTREAL QC
# 45                 SAQ23082 MAGOG MAGOG QC
# 46          APPLE.COM/BILL 866-712-7753 ON
# 47                 SAQ.COM/12424 QUEBEC QC
# 48            CPC / SCP 227730 MONTRÉAL QC
# 49             ADONIS 21943 ANJOU ANJOU QC
# 50  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 51        SUPER C PAT 5963 POINTE AUX TRQC
# 52            MAXI #8987 * POINTE-AUX-TRQC
# 53             ADONIS 21943 ANJOU ANJOU QC
# 54            MAXI #8987 * POINTE-AUX-TRQC
# 55            MAXI #8987 * POINTE-AUX-TRQC
# 56    PHARMACIE VINH THE JIMMY MONTREAL QC
# 57     SAQ23106CARREFOUR DE LA MONTREAL QC
# 58        SUPER C PAT 5963 POINTE AUX TRQC
# 59                   IGA #8168 MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.020   52.89 2023-02-24  2023-02-24
# 4         0.005    6.02 2023-02-24  2023-02-24
# 5         0.005    8.05 2023-02-25  2023-02-27
# 6         0.020  227.93 2023-02-26  2023-02-27
# 7         0.005    2.00 2023-03-01  2023-03-01
# 8         0.005    9.21 2023-03-01  2023-03-01
# 9         0.005   37.50 2023-03-02  2023-03-02
# 10        0.005   40.23 2023-03-04  2023-03-06
# 11        0.005   30.00 2023-03-04  2023-03-06
# 12        0.005   51.50 2023-03-04  2023-03-06
# 13        0.005    9.12 2023-03-07  2023-03-07
# 14        0.005   56.08 2023-03-07  2023-03-07
# 15        0.005   12.42 2023-03-07  2023-03-07
# 16        0.005   23.40 2023-03-09  2023-03-10
# 17        0.005   25.20 2023-03-09  2023-03-10
# 18        0.005   31.97 2023-03-10  2023-03-10
#
#                                     merchant
# 3                   PIAZZETTA MAGOG MAGOG QC
# 4               METRO PLOUFFE MAGOG MAGOG QC
# 5               PROXI EXTRA ORFORD ORFORD QC
# 6                  L'HELICOPTERE MONTREAL QC
# 7       AGENCE DE MOBILITE DURABLMONTREAL QC
# 8     METRO DE LA ROUSSELIER POINTE AUX TRQC
# 9   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 10  LES ANIMALERIES T.D. ZOO POINTE-AUX-TRQC
# 11     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 12          SUPER C PAT 5963 POINTE AUX TRQC
# 13       MAXI & CIE REPENTIGNY REPENTIGNY QC
# 14          SUPER C REPENTIGNY REPENTIGNY QC
# 15      METRO MARQUIS REPENTIG REPENTIGNY QC
# 16     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17                       LE DATE MONTREAL QC
# 18    METRO DE LA ROUSSELIER POINTE AUX TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   65.77 2023-03-10  2023-03-10
# 4         0.005   43.35 2023-03-10  2023-03-10
# 5         0.005   43.91 2023-03-11  2023-03-13
# 6         0.005  126.00 2023-03-11  2023-03-13
# 7         0.005    3.77 2023-03-11  2023-03-13
# 8         0.020   30.00 2023-03-12  2023-03-13
# 9         0.020   32.06 2023-03-12  2023-03-13
# 10        0.005    7.00 2023-03-14  2023-03-14
# 11        0.005  111.68 2023-03-14  2023-03-14
# 12        0.020   78.00 2023-03-16  2023-03-16
# 13        0.005   18.90 2023-03-16  2023-03-17
# 14        0.005   32.90 2023-03-18  2023-03-20
# 15        0.005   28.75 2023-03-18  2023-03-20
# 16        0.005   27.95 2023-03-18  2023-03-20
# 17        0.005    5.92 2023-03-19  2023-03-20
# 18        0.005   33.18 2023-03-19  2023-03-20
# 19        0.005    7.87 2023-03-19  2023-03-20
#
#                                     merchant
# 3           SUPER C PAT 5963 POINTE AUX TRQC
# 4               MAXI #8987 * POINTE-AUX-TRQC
# 5                      ADONIS ANJOU ANJOU QC
# 6        NBX*CENTRECOMROUSSIN 514-6454519 QC
# 7          SAQ23327 REPENTIGNY REPENTIGNY QC
# 8           CAFE LES FRAICHES LASSOMPTION QC
# 9                   DUNNS FAMOUS MONTREAL QC
# 10    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11         AIRBNB * HMT2PREXQ8 AIRBNB.COM GB
# 12  ERABLIERE AU RYTHME DES TSAINT-LIN-LAUQC
# 13     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 14          SUPER C PAT 5963 POINTE AUX TRQC
# 15              MAXI #8987 * POINTE-AUX-TRQC
# 16     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17    MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC
# 18          SUPER C PAT 5963 POINTE AUX TRQC
# 19                     ADONIS ANJOU ANJOU QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   32.65 2023-07-26  2023-07-27
# 4         0.020   64.46 2023-07-27  2023-07-27
# 5         0.005   17.24 2023-07-27  2023-07-27
# 6         0.005   38.20 2023-07-28  2023-07-28
# 7         0.005   29.14 2023-07-28  2023-07-28
# 8         0.005   10.57 2023-07-28  2023-07-28
# 9         0.000   68.94 2023-07-28  2023-07-28
# 10        0.005    9.15 2023-07-29  2023-07-31
# 11        0.005   26.85 2023-07-30  2023-07-31
# 12        0.020   75.37 2023-07-30  2023-07-31
# 13        0.005    4.29 2023-07-31  2023-07-31
# 14        0.020    4.44 2023-07-31  2023-08-01
# 15        0.005   24.47 2023-08-01  2023-08-01
# 16        0.005  137.13 2023-08-01  2023-08-01
# 17        0.005   10.57 2023-08-02  2023-08-02
# 18        0.005   21.92 2023-08-02  2023-08-02
#
#                                     merchant
# 3                    SAQ23082 MAGOG MAGOG QC
# 4              L'OEUFRIER BROMONT BROMONT QC
# 5             JEAN COUTU 045 POINTE AUX TRQC
# 6             SEPAQ 1 800 665 6527 QUEBEC QC
# 7           SUPER C PAT 5963 POINTE AUX TRQC
# 8                      IGA #8168 MONTREAL QC
# 9                REITMANS #443 REPENTIGNY QC
# 10     SUPER C B ST PAUL 261 BAIE SAINT PAQC
# 11             SAQ33532 CLERMONT CLERMONT QC
# 12         PIZZERIA DU BOULEVARD CLERMONT QC
# 13        MARCHE NOTRE DAME 2225 MONTREAL QC
# 14     MCDONALD'S #10630 Q04 BERTHIERVILLEQC
# 15  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 16     LE PAPETIER LE LIBRAIRE REPENTIGNY QC
# 17  LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 18          SUPER C PAT 5963 POINTE AUX TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005  153.20 2023-08-02  2023-08-03
# 4         0.005   59.55 2023-08-03  2023-08-03
# 5         0.005   15.82 2023-08-03  2023-08-04
# 6         0.005   39.98 2023-08-03  2023-08-04
# 7         0.005   40.20 2023-08-04  2023-08-04
# 8         0.005   16.95 2023-08-04  2023-08-04
# 9         0.005   55.12 2023-08-06  2023-08-07
# 10        0.005   27.15 2023-08-06  2023-08-07
# 11        0.005   63.35 2023-08-07  2023-08-07
# 12        0.005    8.41 2023-08-07  2023-08-07
# 13        0.005    4.98 2023-08-07  2023-08-08
# 14        0.000    0.95 2023-08-08  2023-08-08
# 15        0.005   21.24 2023-08-09  2023-08-09
# 16        0.005    9.89 2023-08-11  2023-08-11
# 17        0.005   53.23 2023-08-11  2023-08-11
# 18        0.005   26.57 2023-08-12  2023-08-14
# 19        0.005   24.11 2023-08-12  2023-08-14
# 20        0.005   11.28 2023-08-12  2023-08-14
# 21        0.020   50.00 2023-08-13  2023-08-14
# 22        0.005    4.13 2023-08-14  2023-08-14
# 23        0.020   46.28 2023-08-14  2023-08-14
# 24        0.005    7.60 2023-08-15  2023-08-15
# 25        0.005   15.88 2023-08-15  2023-08-15
# 26        0.005    1.48 2023-08-17  2023-08-17
# 27        0.005   23.43 2023-08-17  2023-08-17
# 28        0.005   91.90 2023-08-18  2023-08-18
# 29        0.005    6.99 2023-08-18  2023-08-18
# 30        0.005   49.34 2023-08-19  2023-08-21
# 31        0.005    4.07 2023-08-19  2023-08-21
# 32        0.005   95.64 2023-08-20  2023-08-21
# 33        0.005   19.99 2023-08-20  2023-08-21
# 34        0.005  142.24 2023-08-22  2023-08-22
# 35        0.005   34.47 2023-08-22  2023-08-22
# 36        0.005    4.29 2023-08-22  2023-08-22
# 37        0.005  229.95 2023-08-23  2023-08-23
#
#                                   merchant
# 3                  SAQ.COM/12424 QUEBEC QC
# 4   SAQ23303 TERREBONNE-MTEE TERREBONNE QC
# 5           IGA EXTRA # 8528 TERREBONNE QC
# 6                  MAXI #8622 LACHENAIE QC
# 7        LA MAISON SIMONS INC (ANJANJOU QC
# 8      SAQ23106CARREFOUR DE LA MONTREAL QC
# 9   AMZN Mktp CA*TA84J1ZZ1 WWW.AMAZON.CAON
# 10                        ETSY ETSY.COM IE
# 11     SAQ23106CARREFOUR DE LA MONTREAL QC
# 12        SUPER C PAT 5963 POINTE AUX TRQC
# 13                   IGA #8168 MONTREAL QC
# 14  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15    AU COIN DU PEDALEUR ET REPENTIGNY QC
# 16            METRO FOGARTY CHARLEMAGNE QC
# 17        ESSO COUCHE-TARD SAINT-LAMBERTQC
# 18  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 19        SUPER C PAT 5963 POINTE AUX TRQC
# 20    PROVIGO LE GARDEUR #85 LE GARDEUR QC
# 21         CDNCANCERSOC-DR 888-955-5455 ON
# 22           PETRO CANADA14110 MONTREAL QC
# 23         LE POKE STATION PAT MONTREAL QC
# 24             RACEROSTER PRISON LONDON ON
# 25                    FOODHERO MONTREAL QC
# 26          APPLE.COM/BILL 866-712-7753 ON
# 27  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 28        SUPER C PAT 5963 POINTE AUX TRQC
# 29                   IGA #8168 MONTREAL QC
# 30  AMZN Mktp CA*TQ7D69XB2 WWW.AMAZON.CAON
# 31    AGENCE DE MOBILITE DURABLMONTREAL QC
# 32  AMZN Mktp CA*TQ5FP7010 WWW.AMAZON.CAON
# 33  AMZN Mktp CA*TQ0828ME2 WWW.AMAZON.CAON
# 34                    RW #2499 MONTREAL QC
# 35          JEAN COUTU 045 POINTE AUX TRQC
# 36              MAXI #8987 POINTE-AUX-TRQC
# 37    SQ *9483-1104 QUEBEC INC.LANORAIE QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   25.00 2023-12-24  2023-12-27
# 4         0.005   53.25 2023-12-24  2023-12-27
# 5         0.020   28.63 2023-12-26  2023-12-27
# 6         0.005   68.39 2023-12-26  2023-12-27
# 7         0.005   53.94 2023-12-26  2023-12-27
# 8         0.020   71.60 2023-12-26  2023-12-27
# 9         0.005   56.75 2023-12-26  2023-12-27
# 10        0.005   34.23 2023-12-27  2023-12-27
# 11        0.005   80.65 2023-12-27  2023-12-28
# 12        0.020  113.96 2023-12-28  2023-12-28
# 13        0.005    5.69 2023-12-28  2023-12-29
# 14        0.005   12.56 2023-12-29  2023-12-29
# 15        0.005   43.63 2023-12-30  2023-12-30
# 16        0.005   14.95 2023-12-31  2023-01-03
# 17        0.005   22.77 2023-12-31  2023-01-03
# 18        0.005   21.60 2023-12-31  2023-01-03
#
#                                   merchant
# 3         Amazon.ca*SD6270PY3 AMAZON.CA ON
# 4    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 5    PETIT QUEBEC REPENTIGNY REPENTIGNY QC
# 6   AMZN Mktp CA*AS0TR8WS3 WWW.AMAZON.CAON
# 7         SUPER C REPENTIGNY REPENTIGNY QC
# 8       METRO EN LIGNE 2445 SAINTE ROSE QC
# 9        SAQ23070 REPENTIGNY REPENTIGNY QC
# 10  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 11            SAQ23199 SAQ.COM MONTREAL QC
# 12      HENRI BRASSERIE FRANCA MONTREAL QC
# 13    AGENCE DE MOBILITE DURABLMONTREAL QC
# 14        SUPER C PAT 5963 POINTE AUX TRQC
# 15          LE DIVINS TANDEM TERREBONNE QC
# 16  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 17        SUPER C PAT 5963 POINTE AUX TRQC
# 18            MAXI #8987 * POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   24.99 2023-12-31  2023-01-03
# 4         0.005    4.60 2023-12-31  2023-01-03
# 5         0.005   16.78 2023-01-04  2023-01-04
# 6         0.000    0.25 2023-01-04  2023-01-04
# 7         0.005   37.93 2023-01-06  2023-01-06
# 8         0.005    8.48 2023-01-06  2023-01-06
# 9         0.005   34.35 2023-01-06  2023-01-06
# 10        0.005   25.00 2023-01-06  2023-01-06
# 11        0.005  183.96 2023-01-07  2023-01-09
# 12        0.005   31.50 2023-01-07  2023-01-09
# 13        0.005   30.03 2023-01-07  2023-01-09
# 14        0.005    4.03 2023-01-08  2023-01-09
# 15        0.005   14.35 2023-01-08  2023-01-09
# 16        0.005    7.98 2023-01-10  2023-01-10
# 17        0.005   26.72 2023-01-10  2023-01-10
# 18        0.005  252.95 2023-01-12  2023-01-12
# 19        0.005   18.18 2023-01-13  2023-01-13
# 20        0.005   32.71 2023-01-14  2023-01-16
# 21        0.020   82.12 2023-01-14  2023-01-16
# 22        0.005   14.74 2023-01-14  2023-01-16
# 23        0.005   21.14 2023-01-14  2023-01-16
# 24        0.005   11.86 2023-01-14  2023-01-16
# 25        0.020   51.14 2023-01-19  2023-01-19
# 26        0.005   11.69 2023-01-20  2023-01-20
# 27        0.005  155.16 2023-01-21  2023-01-23
# 28        0.005   13.85 2023-01-21  2023-01-23
# 29        0.005    8.43 2023-01-21  2023-01-23
# 30        0.005   10.61 2023-01-21  2023-01-23
# 31        0.005   29.52 2023-01-22  2023-01-23
# 32        0.005   27.32 2023-01-23  2023-01-23
# 33        0.005   16.87 2023-01-24  2023-01-24
#
#                                     merchant
# 3                      IGA #8168 MONTREAL QC
# 4        WAL-MART STORE#1169 POINTE-AUX-TRQC
# 5                       Billabong Halifax NS
# 6       AGENCE DE MOBILITE DURABLMONTREAL QC
# 7   LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# 8        LIBRAIRIE RENAUD BRAY REPENTIGNY QC
# 9           SUPER C REPENTIGNY REPENTIGNY QC
# 10     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 11             SP YUL RUN CANADA MONTREAL QC
# 12    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 13                     IGA #8168 MONTREAL QC
# 14          SUPER C PAT 5963 POINTE AUX TRQC
# 15     SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 16              MAXI #8987 * POINTE-AUX-TRQC
# 17                     ADONIS ANJOU ANJOU QC
# 18                   HORIZON ROC MONTREAL QC
# 19                      FOODHERO MONTREAL QC
# 20              MAXI #8987 * POINTE-AUX-TRQC
# 21                  RESTO INDIAN MONTREAL QC
# 22                     IGA #8168 MONTREAL QC
# 23    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 24          SUPER C PAT 5963 POINTE AUX TRQC
# 25          POKE STATION PAT POINTE-AUX-TRBC
# 26    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 27                GLOBOSHOES.COM MONTREAL QC
# 28        SUPER C ST LEONARD SAINT LEONARDQC
# 29                     ADONIS ANJOU ANJOU QC
# 30    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 31          SUPER C PAT 5963 POINTE AUX TRQC
# 32                     ADONIS ANJOU ANJOU QC
# 33              PHARMAPRIX #0061 MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   82.68 2023-01-28  2023-01-30
# 4         0.005   10.58 2023-01-28  2023-01-30
# 5         0.005   38.98 2023-01-28  2023-01-30
# 6         0.000   68.65 2023-01-28  2023-01-30
# 7         0.005   30.85 2023-01-29  2023-01-30
# 8         0.005   66.52 2023-01-29  2023-01-30
# 9         0.005   39.12 2023-01-29  2023-01-30
# 10        0.005   21.58 2023-01-30  2023-01-30
# 11        0.005   81.61 2023-01-30  2023-01-30
# 12        0.005  103.46 2023-02-04  2023-02-06
# 13        0.005   18.87 2023-02-04  2023-02-06
# 14        0.005   11.58 2023-02-05  2023-02-06
# 15        0.005   12.51 2023-02-05  2023-02-06
# 16        0.005   55.72 2023-02-06  2023-02-06
# 17        0.005  216.29 2023-02-07  2023-02-08
# 18        0.020   33.72 2023-02-09  2023-02-09
#
#                                   merchant
# 3      SP MONSIEUR COCKTAIL QUEBEC CITY QC
# 4                    ADONIS ANJOU ANJOU QC
# 5   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 6                  GLOBO #4534 MONTREAL QC
# 7   AMZN Mktp CA*1F3HO5IV3 WWW.AMAZON.CAON
# 8         SUPER C PAT 5963 POINTE AUX TRQC
# 9             MAXI #8987 * POINTE-AUX-TRQC
# 10  AMZN Mktp CA*5002Y9IQ3 WWW.AMAZON.CAON
# 11  AMZN Mktp CA*4L5L22N53 WWW.AMAZON.CAON
# 12                 WINNERS 474 MONTREAL QC
# 13                   ADONIS ANJOU ANJOU QC
# 14                    FOODHERO MONTREAL QC
# 15                   IGA #8168 MONTREAL QC
# 16  AMZN Mktp CA*NQ5PS64O3 WWW.AMAZON.CAON
# 17            SAQ23199 SAQ.COM MONTREAL QC
# 18          TOMATE BASILIC POINTE-AUX-TRQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005    5.00 2023-02-10  2023-02-10
# 4         0.005   64.32 2023-02-10  2023-02-10
# 5         0.005   26.03 2023-02-10  2023-02-10
# 6         0.005   57.20 2023-02-10  2023-02-10
# 7         0.005    6.88 2023-02-10  2023-02-13
# 8         0.020   38.00 2023-02-11  2023-02-13
# 9         0.005    4.75 2023-02-11  2023-02-13
# 10        0.020  100.49 2023-02-11  2023-02-13
# 11        0.005   12.26 2023-02-12  2023-02-13
# 12        0.005   16.65 2023-02-12  2023-02-13
# 13        0.005   15.26 2023-02-12  2023-02-13
# 14        0.000    8.79 2023-02-12  2023-02-13
# 15        0.020  192.38 2023-02-16  2023-02-16
# 16        0.005    3.88 2023-02-18  2023-02-20
# 17        0.005   55.69 2023-02-18  2023-02-20
# 18        0.005   13.37 2023-02-19  2023-02-20
# 19        0.005   26.33 2023-02-20  2023-02-20
# 20        0.005   41.37 2023-02-20  2023-02-20
# 21        0.005  984.81 2023-02-20  2023-02-21
# 22        0.005  984.81 2023-02-20  2023-02-21
# 23        0.005  617.37 2023-02-21  2023-02-21
# 24        0.020   10.00 2023-02-23  2023-02-23
# 25        0.020   10.00 2023-02-23  2023-02-23
#
#                                   merchant
# 3                     FLASHFOOD TORONTO ON
# 4         SUPER C PAT 5963 POINTE AUX TRQC
# 5             MAXI #8987 * POINTE-AUX-TRQC
# 6                 LE BLIND PIG MONTREAL QC
# 7    MAGASIN CDN TIRE #00009 ST LEONARD QC
# 8           DEFI DANIEL LEQUIN JOLIETTE QC
# 9     AGENCE DE MOBILITE DURABLMONTREAL QC
# 10                     PULLMAN MONTREAL QC
# 11                    FOODHERO MONTREAL QC
# 12   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 13                   IGA #8168 MONTREAL QC
# 14                   IGA #8168 MONTREAL QC
# 15          TOMATE BASILIC POINTE-AUX-TRQC
# 16            MAXI #8987 * POINTE-AUX-TRQC
# 17        SUPER C PAT 5963 POINTE AUX TRQC
# 18  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 19        SUPER C REPENTIGNY REPENTIGNY QC
# 20     H&M CA #087- GALERIES REPENTIGNY QC
# 21   AIR CAN* 0141116598585AIRCANADA.COMMB
# 22   AIR CAN* 0141116598586AIRCANADA.COMMB
# 23    EXPEDIA 72495655094635 EXPEDIA.CA ON
# 24       LE CIRCUIT ELECTRIQUE MONTREAL QC
# 25       LE CIRCUIT ELECTRIQUE MONTREAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   18.15 2023-03-23  2023-03-24
# 4         0.020    3.50 2023-03-23  2023-03-24
# 5         0.020    3.50 2023-03-25  2023-03-27
# 6         0.005   70.24 2023-03-25  2023-03-27
# 7         0.005   26.60 2023-03-25  2023-03-27
# 8         0.005    6.98 2023-03-27  2023-03-27
# 9         0.005    6.94 2023-03-27  2023-03-27
# 10        0.005   13.73 2023-03-27  2023-03-27
# 11        0.005    6.99 2023-03-27  2023-03-28
# 12        0.005    7.98 2023-03-28  2023-03-28
# 13        0.020   72.72 2023-03-30  2023-03-30
# 14        0.005   22.54 2023-03-30  2023-03-30
# 15        0.005   82.21 2023-03-30  2023-03-30
# 16        0.005    6.74 2023-03-31  2023-03-31
# 17        0.020    9.98 2023-04-05  2023-04-05
#
#                                   merchant
# 3    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 4      STM HONORE BEAUG DIN101 MONTREAL QC
# 5      STM HONORE BEAUG DIN101 MONTREAL QC
# 6         SUPER C PAT 5963 POINTE AUX TRQC
# 7    SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 8   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 9         SUPER C PAT 5963 POINTE AUX TRQC
# 10            MAXI #8987 * POINTE-AUX-TRQC
# 11                   IGA #8168 MONTREAL QC
# 12  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 13               SUSHISAMA POINTE-AUX-TRQC
# 14        SUPER C PAT 5963 POINTE AUX TRQC
# 15            MAXI #8987 * POINTE-AUX-TRQC
# 16  METRO BOUCHER JEAN MAT SAINT JEAN DEQC
# 17                   BISTROT INT DORVAL QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   87.79 2023-04-06  2023-04-06
# 5         0.005   54.10 2023-04-06  2023-04-06
# 7         0.005   13.31 2023-04-06  2023-04-06
# 9         0.005   48.46 2023-04-07  2023-04-10
# 11        0.005   27.70 2023-04-07  2023-04-11
# 13        0.005  139.12 2023-04-10  2023-04-11
# 15        0.005    6.63 2023-04-12  2023-04-12
# 16        0.005   29.25 2023-04-13  2023-04-14
# 17        0.005   11.52 2023-04-14  2023-04-14
# 18        0.005   64.84 2023-04-14  2023-04-14
# 19        0.005   22.77 2023-04-14  2023-04-14
# 20        0.005   68.40 2023-04-14  2023-04-14
# 21        0.020    3.75 2023-04-15  2023-04-17
# 22        0.005   15.65 2023-04-15  2023-04-17
# 23        0.005    3.99 2023-04-16  2023-04-17
# 24        0.005   35.05 2023-04-16  2023-04-17
# 25        0.005    1.48 2023-04-17  2023-04-17
# 26        0.005    5.23 2023-04-20  2023-04-20
# 27        0.005   16.95 2023-04-20  2023-04-21
# 28        0.005   18.30 2023-04-21  2023-04-21
# 29        0.005    2.86 2023-04-22  2023-04-24
# 30        0.005   48.72 2023-04-23  2023-04-24
# 31        0.020   23.70 2023-04-23  2023-04-24
#
#                                   merchant
# 3            RUBY'S GENERAL STORE BRYCE UT
# 5       SHELL OIL10007497018 CEDAR CITY UT
# 7          BRYCE CANYON NATURAL H BRYCE UT
# 9         ZION NATIONAL PARK SPRINGDALE UT
# 11        TOWN OF SPRINGDALE SPRINGDALE UT
# 13    2300 SAHARA HOTEL OPERA LAS VEGAS NV
# 15            MAXI #8987 * POINTE-AUX-TRQC
# 16   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 17  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 18        SUPER C PAT 5963 POINTE AUX TRQC
# 19            MAXI #8987 * POINTE-AUX-TRQC
# 20   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 21         CAPULUS CAFE MOBILE MONTREAL QC
# 22      SAQ23064 SHERBROOKE ES MONTREAL QC
# 23        SUPER C PAT 5963 POINTE AUX TRQC
# 24   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 25          APPLE.COM/BILL 866-712-7753 ON
# 26            MAXI #8987 * POINTE-AUX-TRQC
# 27   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 28   SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# 29            MAXI #8987 * POINTE-AUX-TRQC
# 30  METRO DE LA ROUSSELIER POINTE AUX TRQC
# 31   SOCIETE DES TRAVERSIER SOREL-TRACY QC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   17.75 2023-08-24  2023-08-24
# 4         0.005   24.81 2023-08-24  2023-08-24
# 5         0.005   19.69 2023-08-24  2023-08-24
# 6         0.005   10.00 2023-08-24  2023-08-25
# 7         0.005   23.73 2023-08-24  2023-08-25
# 8         0.005   21.83 2023-08-25  2023-08-25
# 9         0.005   11.27 2023-08-25  2023-08-25
# 10        0.005  264.42 2023-08-27  2023-08-28
# 11        0.005   28.31 2023-08-27  2023-08-28
# 12        0.005    9.83 2023-08-27  2023-08-28
# 13        0.000   39.52 2023-08-27  2023-08-28
# 14        0.005   10.32 2023-08-28  2023-08-28
# 15        0.000   66.00 2023-08-28  2023-08-28
# 16        0.000   21.83 2023-08-28  2023-08-28
# 17        0.005   45.98 2023-08-29  2023-08-30
# 18        0.005   68.03 2023-08-30  2023-08-30
#
#                                    merchant
# 3                      FOODHERO MONTREAL QC
# 4    METRO DE LA ROUSSELIER POINTE AUX TRQC
# 5          SUPER C PAT 5963 POINTE AUX TRQC
# 6                     IGA #8168 MONTREAL QC
# 7                   MAXI #8622 LACHENAIE QC
# 8    AMZN Mktp CA*T35OE2JH2 WWW.AMAZON.CAON
# 9                MAXI #8987 POINTE-AUX-TRQC
# 10       SP CANADA VALISE DEP ST-LAURENT QC
# 11       QUEBECLOISIRS PLACE VE MONTREAL QC
# 12              ADONIS 21943 ANJOU ANJOU QC
# 13                  RW & CO. #2216 ANJOU QC
# 14   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 15     NBX*CENTRECOMROUSSIN POINTE-AUX-TRQC
# 16   AMZ*PremiumpartsWhosal WWW.AMAZON.CAON
# 17  WOLVERINE WORLDWIDE CANADMISSISSAUGA ON
# 18    INSCRIPTIONENLIGNE.CA SAINT-EUSTACHQC
#     BONIDOLLARS  amount       date record_date  \
# 3         0.005   28.74 2023-08-31  2023-08-31
# 4         0.005    7.37 2023-09-01  2023-09-01
# 5         0.005   20.00 2023-09-03  2023-09-05
# 6         0.020    6.89 2023-09-03  2023-09-05
# 7         0.005   25.00 2023-09-03  2023-09-05
# 8         0.005   53.72 2023-09-04  2023-09-05
# 9         0.005   39.05 2023-09-04  2023-09-05
# 10        0.000   53.72 2023-09-04  2023-09-05
# 11        0.000   10.33 2023-09-04  2023-09-05
# 12        0.005  886.32 2023-09-05  2023-09-05
# 13        0.005  886.32 2023-09-05  2023-09-05
# 14        0.005  781.32 2023-09-05  2023-09-05
# 15        0.020   57.00 2023-09-08  2023-09-08
# 16        0.005   17.30 2023-09-10  2023-09-11
# 17        0.000    3.64 2023-09-11  2023-09-11
# 18        0.005    9.18 2023-09-12  2023-09-12
# 19        0.005   87.34 2023-09-14  2023-09-14
# 20        0.005    7.60 2023-09-15  2023-09-15
# 21        0.005  131.84 2023-09-16  2023-09-18
# 22        0.005    1.48 2023-09-17  2023-09-18
# 23        0.005   51.48 2023-09-19  2023-09-19
# 24        0.005   36.44 2023-09-19  2023-09-19
# 25        0.005   48.23 2023-09-21  2023-09-21
# 26        0.005   68.99 2023-09-21  2023-09-21
# 27        0.005   49.38 2023-09-22  2023-09-22
# 28        0.020   41.51 2023-09-22  2023-09-22
# 29        0.020   32.40 2023-09-23  2023-09-25
# 30        0.020   29.08 2023-09-23  2023-09-25
#
#                                   merchant
# 3       UNARBREPOURMONQUARTIER MONTREAL QC
# 4   METRO DE LA ROUSSELIER POINTE AUX TRQC
# 5    SQ *FERME LA VRAIE VIE Saint-Zenon QC
# 6              NETFLIX.COM 866-716-0414 ON
# 7      SQ *MIEL MORAND INC. Saint-Zenon QC
# 8        LIBRAIRIE RENAUD BRAY MONTREAL QC
# 9        LIBRAIRIE RENAUD BRAY MONTREAL QC
# 10       LIBRAIRIE RENAUD BRAY MONTREAL QC
# 11       LIBRAIRIE RENAUD BRAY MONTREAL QC
# 12            RAM 1479652367226MONTREAL QC
# 13            RAM 1479652367225MONTREAL QC
# 14            RAM 1479652367222MONTREAL QC
# 15        CAFE LES FRAICHES LASSOMPTION QC
# 16                    FOODHERO MONTREAL QC
# 17                    FOODHERO MONTREAL QC
# 18          JEAN COUTU 045 POINTE AUX TRQC
# 19  AMZN Mktp CA*TX9DD0OD0 WWW.AMAZON.CAON
# 20    AGENCE DE MOBILITE DURABLMONTREAL QC
# 21                 SAQ.COM/12424 QUEBEC QC
# 22          APPLE.COM/BILL 866-712-7753 ON
# 23  AMZN Mktp CA*TX0II8Z91 WWW.AMAZON.CAON
# 24                    FOODHERO MONTREAL QC
# 25  AMZN Mktp CA*TX9JK69D0 WWW.AMAZON.CAON
# 26      TUANGO INC/#LD-0068960 MONTREAL QC
# 27  AMZN Mktp CA*T188C8AS2 WWW.AMAZON.CAON
# 28              3 BRASSEURS ANJOU ANJOU QC
# 29            PUB LORD WILLIAM MONTREAL QC
# 30                BUVETTE JUNE MONTREAL QC
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [101], line 77
#      75     for term in term_list:
#      76         query |= Q(merchant__contains=term)
# ---> 77         for t in t_list.filter(query):
#      78             print(t.merchant, t.amount)
#      82         # t.category = budget_item
#      83         # print(t.category)
#      84
#    (...)
#      89 #     else:
#      90 #         print(t, t.merchant)
#
# AttributeError: 'list' object has no attribute 'filter'

# %% [markdown]
# # Transactions

# %% [markdown]
# ## Instantiate user

# %%
evaluation_date = datetime.today()
b = timezone.make_aware(datetime(evaluation_date.year, evaluation_date.month, 1))
e = b + relativedelta(months=1) - timedelta(days=1)

# %% [markdown]
# ## Read CSV

# %%
file_path = 'data/Transactions.csv'
data_list = []
with open(file_path, 'rb') as rawdata:
    result = chardet.detect(rawdata.read())
# with open(file_path, 'r', encoding='utf-8-sig') as csvfile:
with open(file_path, 'r', encoding=result['encoding']) as csvfile:
    # Create a DictReader object
    csv_reader = csv.DictReader(csvfile)
    # Iterate through each row (each row is a dictionary)
    for row in csv_reader:
        if row["date"]:
            data_list.append(row)

# %% [markdown]
# ## Delete previous transaction

# %%
Transaction.objects.all().delete()

# %% [markdown]
# ## Create fake transaction

# %% [markdown]
# boy = timezone.make_aware(datetime(2022, 1, 1))
# generated_date = boy
# generated_date_list = []
# fixed_cost = [b for b in Budget.objects.filter(cost_type__name="Fixe")]
# variable_cost = [b for b in Budget.objects.filter(cost_type__name="Variable") if b.spending_item_name != "Salaire"]
#
# mean = 0  # Mean of the normal distribution (zero for no bias)
#
# while generated_date <= timezone.make_aware(datetime.today() - relativedelta(months=3)):
#     generated_date = generated_date + relativedelta(months=1)
#     generated_date_list.append(generated_date)
#     generated_date_index = generated_date_list.index(generated_date)
#
#     if generated_date_index == 0:
#         b = boy
#     else:
#         b = generated_date_list[generated_date_index - 1]
#
#     for cost in variable_cost:
#         amount = cost.calculate_amount()
#         if cost.calculate_amount() < 100:
#             # number of transactions should be beween 0 and 2
#             num_transactions = random.randint(1, 2)  # Random number of transactions
#         else:
#             num_transactions = random.randint(1, 6)
#
#         for transaction in range(num_transactions):
#             # generate days
#             transaction_day = random.randint(1, 28)
#             transaction_date = generated_date.replace(day=transaction_day)
#             transaction_amount = amount / num_transactions + np.random.normal(mean, amount*0.05)
#             # print(transaction_date, cost.spending_item_name, amount, round(transaction_amount, 2))
#
#             x = Transaction(category = cost,
#                             date = transaction_date,
#                             merchant = "Faked Transaction",
#                             amount = transaction_amount,
#                             note = " ",
#                             user = user)
#             x.save()
#
#     for cost in fixed_cost:
#         transaction_amount = cost.calculate_amount()
#         transaction_day = random.randint(1, 28)
#         transaction_date = generated_date.replace(day=transaction_day)
#
#         y = Transaction(category = cost
#                         ,date = transaction_date
#                         ,merchant = "Faked Transaction"
#                         ,amount = transaction_amount
#                         ,note = " "
#                         ,user = user)
#         y.save()

# %% [markdown]
# ## Create transaction in DB

# %%
for row_dict in data_list:
    transaction = Transaction()
    for k,v in row_dict.items():
        # generate a random day
        d=random.randint(1, 30)
        
        if d < 10:
            d=str(0)+str(d)
        else:
            d=str(d)
            
        if k=="date":
            # print(v)
            try:
                # print(v)
                v = timezone.make_aware(datetime.strptime(v, '%Y-%m-%d'))
                v = v.replace(day=int(d))
            except:
                y= "2023"
                if v.strip()=="sept":
                    m="sep"
                elif v.strip()=="sep":
                    m=v
                else:
                    # print("********error", v)
                    m=v
                l=[y,m,d]
                v="-".join(l)
                # print("HHHHH", v)
                v = timezone.make_aware(datetime.strptime(v, '%Y-%b-%d'))
                
        if k=="category":
            try:
                if v == "Frais garde":
                    v = "frais de garde"
                if v == "imprévue / auto":
                    v = "imprévues"
                if v == "voiture 50000 dans 5 ans":
                    v = "voiture 50000 dans 5 ans"
                if v == "Pneus voiture 4 ans 1000":
                    v = "pneus" 
                v = Budget.objects.get(spending_item_name=v)
            except:
                pass
            
        if k=="source":
            v = TransactionSource.objects.get(id=1)
        if k=="montant":
            k="amount"
            v = float(v.replace("(", "").replace(")", ""))
            # print(k,v)
            
        
        setattr(transaction, k, v)
    setattr(transaction, 'user', user)
    transaction.save()
    # print(transaction)
    # print(transaction)

# %%
def get_payment_dict(b):
        # Specify the year and month for which you want to generate the dictionary
        year = b.year
        month = b.month

        # Calculate the first day of the specified month
        b = datetime(year, month, 1)

        # Calculate the last day of the specified month
        if month == 12:
            end_date = datetime(year + 1, 1, 1) - timedelta(days=1)
        else:
            end_date = datetime(year, month + 1, 1) - timedelta(days=1)

        # date_dict now contains the dates for the specified year and month with values initialized to 0
        return {b.date() + timedelta(days=i): 0 for i in range((end_date - b).days + 1)} 

print(get_payment_dict(b))

# %% [markdown]
# ## Get transaction for category between dates

# %%
category = Budget.objects.get(spending_item_name ="epicerie")
b2 = b - relativedelta(months=1)
transaction = Transaction.objects.filter(user=user, category=category, date__range=(b2, e)).order_by('date')


for t in transaction:
    print(t)

# %% [markdown]
# ## Get transaction for category, by merchant, between date

# %%
from django.db.models import Sum

# Group transactions by merchant and sum amounts
total_amount_by_merchant = transaction.values('merchant').order_by('merchant').annotate(total_amount=Sum('amount'))

# result is now a QuerySet with the aggregated data
total
for item in total_amount_by_merchant:
    merchant = item['merchant']
    total_amount = item['total_amount']
    print(f"Merchant: {merchant}, Total Amount: {total_amount}")
print(category.calculate_amount())

# %% [markdown]
# ## Historical avareage by categories

# %%
from django.db.models import F, Sum
from datetime import datetime, timedelta

# Find the earliest and latest dates for your data
earliest_date = Transaction.objects.earliest('date').date
latest_date = Transaction.objects.latest('date').date

# Calculate the number of days in the dataset
num_days = (latest_date - earliest_date).days

# Create a list of dates for the month, from the 1st to the 31st
dates_in_month = [earliest_date + timedelta(days=i) for i in range(num_days)]

# Get a list of distinct categories
transactions = Transaction.objects.filter(
    category__cost_type__name="Variable").values(
    'category__spending_item_name').distinct()
# transactions
# Calculate daily historical averages for each category
daily_averages_by_category = []

for transaction in transactions:
    category_name = transaction["category__spending_item_name"]
    print(category_name)
    for day in range(1, 32):
        # Calculate the average spending for the given category and date
        tr = Transaction.objects.filter(
            category__spending_item_name=category_name, 
            # date__day=day
        ).exclude(merchant="Balance Transfert")
        data_list = [t.amount for t in tr if t.date.day==day]
        number = len(data_list)
        total = sum(data_list)
        if number > 0:
            average = total / number
        else:
            average = 0
        
        daily_averages_by_category.append({
                'category_name': category_name,
                'day': day,
                'average_spent': average,
            })

# %%
daily_averages_by_category

# %% [markdown]
# ## Reconcilliation

# %%
boy = timezone.make_aware(datetime(2023, 9, 1))
bom = timezone.make_aware(datetime(datetime.today().year, datetime.today().month, 1))
number_of_days = timezone.make_aware(datetime.today()) - bom
print("Début d'année", boy, "Début de mois", bom, "Nombre de jour depuis debut de mois", number_of_days.days)



def create_date_list(boy, bom, number_of_days):
    eom_date_list = []
    n=1
    while boy + relativedelta(months=n) <= bom:
        eom_date_list.append(boy + relativedelta(months=n))
        n +=1

    date_list = []
    # get the amount per categorie per months since the BOY
    for eom_date in eom_date_list:
        # print(eom_date, eom_date_list.index(eom_date))

        if eom_date_list.index(eom_date) == 0:
            b = boy
            e = eom_date
        else:
            b = eom_date_list[eom_date_list.index(eom_date)-1]
            e = eom_date
        date_list.append((b,e))
    date_list.append((e, e + timedelta(days=number_of_days.days)))
    
    return date_list

date_list = create_date_list(boy, bom, number_of_days)
# print(date_list)
transactions_qs = Transaction.objects.filter(user=user)

budget_qs = Budget.objects.filter(owner=user)

def get_transaction_between_dates(b, e, transactions):
    transactions_dict={"start":b, 
                       "end":e, 
                       "transactions": {} 
                      }
    for t in transactions:
    # print(t.category.spending_item_name, t.amount)
        if t.date >= b and t.date < e and t.category.spending_item_name in transactions_dict["transactions"].keys():
            transactions_dict["transactions"][t.category.spending_item_name] += t.amount
        elif t.date >= b and t.date < e:
            transactions_dict["transactions"][t.category.spending_item_name] = t.amount
    return transactions_dict

def get_transaction_budget_data_dict(b, e, transactions):
    # print("*****************", b, e)
    number_of_days_in_month = calendar.monthrange(b.year, b.month)[1]
    number_of_date_between_dates = e-b
    #  the whole month has passed
    #  get monthly data
    if number_of_days_in_month == number_of_date_between_dates.days:

        budget_data_dict = {b.spending_item_name: b.calculate_amount() 
                       for b in budget_qs
                      }
    #  current month
    #  use number_of_day
    else:
        budget_data_dict = {b.spending_item_name: b.calculate_amount(frequency_name="Daily") * number_of_days.days 
                       for b in budget_qs
                      }

    transaction_data_dict = get_transaction_between_dates(b, e, transactions)

    return transaction_data_dict, budget_data_dict


def get_budgeted_vs_spent(date_list, transactions):
    monthly_reconciliation_list = []
    # monthly_reconciliation_ = []
    for b, e in date_list:
        monthly_reconciliation_dict = {'b': b, 
                                       'e': e, 
                                       'reconcilliation_data': {} 
                                      }
        
        transaction_data_dict, budget_data_dict = get_transaction_budget_data_dict(b, e, transactions)
        
        for name, amount in transaction_data_dict['transactions'].items():
            # print(name, round(amount, 2), round(budget_data_dict[name], 2))
            monthly_reconciliation_dict['reconcilliation_data'][name]= {"budgeté": round(budget_data_dict[name], 2),
                                                                        "dépensé": round(amount, 2),
                                                                        "différence": round(budget_data_dict[name] - amount, 2)
                                                                        }
            
        monthly_reconciliation_list.append(monthly_reconciliation_dict)
                                                                 
    return monthly_reconciliation_list
    



def create_transactions(monthly_reconciliation_list = get_budgeted_vs_spent(date_list, transactions_qs)):
    montant_total = 0
    for dict_list in monthly_reconciliation_list:
        # print("********************")
        # print(dict_list['b'], dict_list['e'])
        # print("********************")
        number_of_days_in_month = calendar.monthrange(dict_list['b'].year, dict_list['b'].month)[1]
        number_of_date_between_dates = dict_list['e'] - dict_list['b']
        #  the whole month has passed
        #  get monthly data
        if number_of_days_in_month == number_of_date_between_dates.days:
            for item_name, data in dict_list['reconcilliation_data'].items():
                if data["différence"] != 0:
                    dernier_jour_du_mois = dict_list['e'] - timedelta(days=1)
                    t1 = Transaction(category = Budget.objects.get(spending_item_name=item_name), 
                                     # date = timezone.make_aware(dernier_jour_du_mois),  
                                     date = dernier_jour_du_mois, 
                                     amount = data["différence"], 
                                     merchant = "Balance Transfert", 
                                     note = f"Annulation de la balance du mois {dict_list['b'].strftime('%B')}",
                                     user = user
                         )
                    # t1.save()
                    # t2.save()
                    print("  ", item_name, data["budgeté"], data["dépensé"], data["différence"])
                    montant_total += data["différence"]
                    
create_transactions(monthly_reconciliation_list = get_budgeted_vs_spent(date_list, transactions_qs))

# %% [markdown]
# ## Current month reconcilliation

# %%
# la somme des différences doivent etre appliquées au budget
def get_current_month_variable_expenses_reconciliation(evaluation_date = None):
    
    if evaluation_date == None:
        b = timezone.make_aware(datetime(datetime.today().year, datetime.today().month, 1))
        e = timezone.make_aware(datetime(datetime.today().year, datetime.today().month, 1) + relativedelta(months=1) - timedelta(days=1))
        evaluation_date = e
    else:
        assert isinstance(evaluation_date, str), "La date du départ doit etre une string recut " + str(type(b))
        evaluation_date = timezone.make_aware(datetime.strptime(evaluation_date, "%Y-%m-%d"))
        b = timezone.make_aware(datetime(evaluation_date.year, evaluation_date.month, 1))
        e = b + relativedelta(months=1) - timedelta(days=1)
        
    ratio = evaluation_date.day / calendar.monthrange(datetime.today().year, datetime.today().month)[1]

    
    data_dict = {"start_date": b, 
                 "end_date": e,
                 "evaluation_date": evaluation_date,
                 "ratio": ratio,
                 "budget_data": {}
                }
    print(b, e)
    print(ratio)

    carried_over_amount_dict={}
    # get blance transfer up to beginin of period exclude what's beyond the evaluations date
    for t in Transaction.objects.exclude(date__gt=evaluation_date).filter(user=user, merchant="Balance Transfert"):
        if t.category in carried_over_amount_dict.keys():
            carried_over_amount_dict[t.category] += t.amount
        else:
            carried_over_amount_dict[t.category] = t.amount

    spent_amount_dict={}
    for t in Transaction.objects.filter(user=user, date__range=(b, evaluation_date)).exclude(merchant="Balance Transfert"):
        if t.category in spent_amount_dict.keys():
            spent_amount_dict[t.category] += t.amount
        else:
            spent_amount_dict[t.category] = t.amount


    for b in Budget.objects.filter(owner=user).exclude(accounting_category__name="Revenus").exclude(cost_type__name="Fixe"):
        budget_item_dict = {}
        if b in carried_over_amount_dict.keys():
            carried_over_amount = carried_over_amount_dict[b] 
        else:
            carried_over_amount = 0

        if b in spent_amount_dict.keys():
            spent_amount = spent_amount_dict[b]
        else:
            spent_amount = 0



        data_dict["budget_data"][b.spending_item_name] = {"carried_over_from_previous_months": round(carried_over_amount, 2), 
                                                          "bi_weekly_amount": b.calculate_amount(frequency_name="Bi-Weekly"), 
                                                          "monthly_amount": b.calculate_amount(),
                                                          "Cummulative amount": b.calculate_amount() + round(carried_over_amount, 2),
                                                          "spent_this_month": round(spent_amount, 2),
                                                          "remainder_for_the_month": round(b.calculate_amount() + carried_over_amount - spent_amount, 2)}
    return data_dict
            

get_current_month_variable_expenses_reconciliation("2023-10-22")

# %% [markdown]
# ### Reconcilliation carried over from previous months

# %%
evaluation_date = "2023-09-10"
evaluation_date = timezone.make_aware(datetime.strptime(evaluation_date, "%Y-%m-%d"))

for t in Transaction.objects.exclude(date__gt=evaluation_date).filter(user=user, category__spending_item_name="epicerie").order_by('date'):
    print(t,t.merchant)
    
# carried_over_amount_dict={}
# # get blance transfer up to beginin of period exclude what's beyond the evaluations date
# for t in Transaction.objects.filter(user=user, merchant="Balance Transfert").exclude(date__lte=evaluation_date):
#     if t.category in carried_over_amount_dict.keys():
#         carried_over_amount_dict[t.category] += t.amount
#     else:
#         carried_over_amount_dict[t.category] = t.amount
        
# print(carried_over_amount_dict)

# %% [markdown]
# ## Transaction view

# %%
from django.db.models import F, Sum, Count, Avg, Max, Min
evaluation_date=None
evaluation_date="2023-10-29"
budget_item_id=809

if evaluation_date == None:
    evaluation_date = timezone.make_aware(datetime.today())
else:
    assert isinstance(evaluation_date, str), "La date du départ doit etre une string recut " + str(type(b))
    evaluation_date = timezone.make_aware(datetime.strptime(evaluation_date, "%Y-%m-%d"))
    
b = timezone.make_aware(datetime(evaluation_date.year, 
                                 evaluation_date.month, 
                                 1)
                       )
e = b + relativedelta(months=1) - timedelta(days=1)


previous_month_random_date = evaluation_date - relativedelta(months=1)
previous_month_start_date = datetime(previous_month_random_date.year, 
                                     previous_month_random_date.month,
                                    1)

previous_eom_date = b - timedelta(days=1)


next_month_random_date = evaluation_date + relativedelta(months=1)
next_month_start_date = datetime(next_month_random_date.year, 
                                 next_month_random_date.month,
                                1)

next_eom_date = b + relativedelta(months=2)


budget_item = Budget.objects.get(id=budget_item_id)
all_transactions = Transaction.objects.filter(user__id=user.id, 
                                              category__id=budget_item_id, # get all transaction for that budget item
                                              date__range=(previous_month_start_date, next_eom_date) # to get the previous month's transfert
                                              ).order_by('date')

previous_month_transactions = all_transactions.filter(date__range=(previous_month_start_date, previous_eom_date))
current_month_transactions = all_transactions.filter(date__range=(b, e))
next_month_transactions = all_transactions.filter(date__range=(next_month_start_date, next_eom_date))

# remove transactions from the last day of the previous month inscluding the cash transfert
current_month_transactions_total = round(sum([t.amount for t in current_month_transactions]), 2)
previous_month_transfer = sum([t.amount for t in previous_month_transactions.filter(merchant="Balance Transfert")])
# transaction_total

d = {'previous_month_exists': previous_month_transactions.exists(), 
     'next_month_exists': next_month_transactions.exists(), 
     # 'previous_month_url': reverse('your_view_name', kwargs={'budget_item_id': budget_item_id, 'evaluation_date': previous_eom_date.strftime('%Y-%m-%d')}), 
     # 'next_month_url': reverse('your_view_name', kwargs={'budget_item_id': budget_item_id, 'evaluation_date': previous_eom_date.strftime('%Y-%m-%d')})
    }

print(f"Begining of period is {b.date()} the evaluation date is {evaluation_date.date()} and the last day of the previous month is {previous_eom_date.date()}", transaction_total)
print(previous_month_transfer)
print(previous_month_start_date.date(), previous_eom_date.date())
print(b.date(), e.date())
print(next_month_start_date.date(), next_eom_date.date())
print(d['previous_month_exists'], d['next_month_exists'], current_month_transactions_total )

# %% [markdown]
# ## Budget Item cumulative spending for a view

# %%
evaluation_date="2023-10-29"
budget_item_id=745

if evaluation_date == None:
    evaluation_date = timezone.make_aware(datetime.today())
else:
    assert isinstance(evaluation_date, str), "La date du départ doit etre une string recut " + str(type(b))
    evaluation_date = timezone.make_aware(datetime.strptime(evaluation_date, "%Y-%m-%d"))
    
b = timezone.make_aware(datetime(evaluation_date.year, 
                                 evaluation_date.month, 
                                 1)
                       )
e = b + relativedelta(months=1) - timedelta(days=1)


transaction_data_dict={}

for t in Transaction.objects.filter(user=user, 
                                    date__range=(b, evaluation_date), 
                                    category__id=budget_item_id).order_by('date'):
    if t.date in transaction_data_dict.keys():
        transaction_data_dict[t.date.date()] += t.amount
    else:
        transaction_data_dict[t.date.date()] = t.amount
        


dates, values = zip(*transaction_data_dict.items())

cumulative_values = [round(sum(values[:i]), 2) for i in range(len(values))]

# %% [markdown]
# ### take 2

# %%
evaluation_date="2023-10-29"
budget_item_id=745

if evaluation_date == None:
    evaluation_date = timezone.make_aware(datetime.today())
else:
    assert isinstance(evaluation_date, str), "La date du départ doit etre une string recut " + str(type(b))
    evaluation_date = timezone.make_aware(datetime.strptime(evaluation_date, "%Y-%m-%d"))
    
b = timezone.make_aware(datetime(evaluation_date.year, 
                                 evaluation_date.month, 
                                 1)
                       )
e = b + relativedelta(months=1) - timedelta(days=1)


def get_payment_dict(b):
    # Specify the year and month for which you want to generate the dictionary
    year = b.year
    month = b.month

    # Calculate the first day of the specified month
    b = datetime(year, month, 1)

    # Calculate the last day of the specified month
    if month == 12:
        end_date = datetime(year + 1, 1, 1) - timedelta(days=1)
    else:
        end_date = datetime(year, month + 1, 1) - timedelta(days=1)

    # date_dict now contains the dates for the specified year and month with values initialized to 0
    return {b.date() + timedelta(days=i): 0 for i in range((end_date - b).days + 1)}

d = get_payment_dict(b)

for t in Transaction.objects.filter(user=user, 
                                    date__range=(b, evaluation_date), 
                                    category__id=budget_item_id).order_by('date'):
    
    if t.date.date() in d.keys():
        d[t.date.date()] += t.amount
        
        
value = [256]*len(d)
print(value)

# %% [markdown]
# # Calcule prestation familiale

# %%
revenus_familialle_net = 26 * 2500
revenus_familialle_net
revenus = 2 * 6275
revenus

# %% [markdown]
# # Transaction No categories

# %%
transactions_with_empty_categories = Transaction.objects.annotate(
    merchant_categories_count=Count('merchant_2__categories')
).filter(merchant_categories_count=0)

# %%
transactions_with_empty_categories
len(transactions_with_empty_categories)

# %%
a = Merchant.objects.get(name="AMZN Mktp CA*T10UZ0KR0 WWW.AMAZON.CAON")
a.categories.all()

# %%
for t in Transaction.objects.all():
    if t.source.id == 4 and t.category is None:
        print(t.merchant)

# %%
t = Transaction.objects.all()
t.delete()
m =  Merchant.objects.all()
m.delete()
pdf = UploadedPDF.objects.all() 
pdf.delete()

# %%
 


eom_date_list = []
n=1
while boy + relativedelta(months=n) <= bom:
    eom_date_list.append(boy + relativedelta(months=n))
    n +=1
    
budgeted_list = [{b.spending_item_name:{"YTD":round(b.calculate_amount()*n + 
                                                    b.calculate_amount(frequency_name="Daily")*number_of_days.days, 0),
                                        "MTD":round(b.calculate_amount(frequency_name="Daily")*number_of_days.days, 0)}} 
                      for b in Budget.objects.filter(owner=user)]
print("********************")
ytd_list_dict = {t.category.spending_item_name: t.amount for t in Transaction.objects.filter(user=user) if t.date.date() > boy}

ytd_transactions_dict={}
for t in Transaction.objects.filter(user=user):
    # print(t.category.spending_item_name, t.amount)
    if t.date.date() > boy and t.category.spending_item_name in ytd_transactions_dict.keys():
        ytd_transactions_dict[t.category.spending_item_name] += t.amount
    elif t.date.date() > boy:
        ytd_transactions_dict[t.category.spending_item_name] = t.amount
    
for budget_dict in budgeted_list:
    for budget_category, data in budget_dict.items():
        if budget_category in ytd_transactions_dict.keys():
            pass
            # print(budget_category, "Budgeted", data["YTD"], "Spent", round(transactions_dict[budget_category]))
    
def get_transaction_between_dates(b, e):
    transactions_dict={"start":b, 
                       "end":e, 
                       "transactions": {} 
                      }
    for t in Transaction.objects.filter(user=user):
    # print(t.category.spending_item_name, t.amount)
        if t.date.date() > b and t.date.date() < e and t.category.spending_item_name in transactions_dict["transactions"].keys():
            transactions_dict["transactions"][t.category.spending_item_name] += t.amount
        elif t.date.date() > b and t.date.date() < e:
            transactions_dict["transactions"][t.category.spending_item_name] = t.amount
    return transactions_dict
date_list = []
# get the amount per categorie per months since the BOY
for eom_date in eom_date_list:
    # print(eom_date, eom_date_list.index(eom_date))
    
    if eom_date_list.index(eom_date) == 0:
        b = boy
        e = eom_date
    else:
        b = eom_date_list[eom_date_list.index(eom_date)-1]
        e = eom_date
    date_list.append((b,e))
date_list.append((e, e + timedelta(days=number_of_days.days)))
    
for b, e in date_list:
    print(b, e)

# %%
def get_transaction_between_dates(b, e, transactions):
    transactions_dict={"start":b, 
                       "end":e, 
                       "transactions": {} 
                      }
    for t in transactions:
    # print(t.category.spending_item_name, t.amount)
        if t.date.date() >= b and t.date.date() < e and t.category.spending_item_name in transactions_dict["transactions"].keys():
            transactions_dict["transactions"][t.category.spending_item_name] += t.amount
        elif t.date.date() >= b and t.date.date() < e:
            transactions_dict["transactions"][t.category.spending_item_name] = t.amount
    return transactions_dict

# %%
boy = datetime(2023, 9, 1).date()
bom = datetime(datetime.today().year, datetime.today().month, 1).date()
number_of_days = datetime.today().date() - bom

def create_date_list(boy, bom, number_of_days):
    eom_date_list = []
    n=1
    while boy + relativedelta(months=n) <= bom:
        eom_date_list.append(boy + relativedelta(months=n))
        n +=1

    date_list = []
    # get the amount per categorie per months since the BOY
    for eom_date in eom_date_list:
        # print(eom_date, eom_date_list.index(eom_date))

        if eom_date_list.index(eom_date) == 0:
            b = boy
            e = eom_date
        else:
            b = eom_date_list[eom_date_list.index(eom_date)-1]
            e = eom_date
        date_list.append((b,e))
    date_list.append((e, e + timedelta(days=number_of_days.days)))
    
    return date_list

# %%
def get_budget_data(b, e, budget_qs, number_of_days):
    for b, e in date_list:
        # print("*****************", b, e)
        number_of_days_in_month = calendar.monthrange(b.year, b.month)[1]
        number_of_date_between_dates = e-b
        #  the whole month has passed
        #  get monthly data
        if number_of_days_in_month == number_of_date_between_dates.days:

            budget_dict = {b.spending_item_name: b.calculate_amount() 
                           for b in budget_qs
                          }
        #  current month
        #  use number_of_day
        else:
            budget_dict = {b.spending_item_name: b.calculate_amount(frequency_name="Daily") * number_of_days.days 
                           for b in budget_qs
                          }

        data_dict = get_transaction_between_dates(b, e, transactions_qs)
        return data_dict

# %%
date_list = create_date_list(boy, bom, number_of_days)
budget_qs
transactions_qs

for b, e in date_list:
    print("*********", b, e)
    
    budget_dict = get_budget_data(b, e, budget_qs, number_of_days)
    transaction_dict = get_transaction_between_dates(b, e, transactions_qs)
    
    for name, amount in transaction_dict['transactions'].items():
        print(name, round(amount), round(budget_dict[name]))
        if round(budget_dict[name]) - round(amount) != 0 and b.month < datetime.today().month:
            last_day_of_month = e - timedelta(days=1)
            print("transfert",name,  round(budget_dict[name] - amount, 2))
            t_1 = Transaction(category=Budget.objects.get(spending_item_name=name), 
                        date=last_day_of_month, 
                        amount= - round(budget_dict[name] - amount, 2), 
                        note= "Transfert fin de moi" + name)
            # t_1.save()
            print(t_1)
            t_2 = Transaction(category=Budget.objects.get(spending_item_name=name), 
                        date=e, 
                        amount= round(budget_dict[name] - amount, 2), 
                        note= "Transfert fin de moi" + name)
            # t_2.save()
            print(t_2)
