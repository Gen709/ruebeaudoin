# %%
from django.contrib.auth.models import User

# %%
user = User.objects.get(id=1)

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import tabula
from investment.models import VisaDesjardinsTransaction  # Make sure to import your VisaDesjardinsTransaction module

class VisaDesjardinsPdfTransactionProcessor:
    def __init__(self, file_path, user):
        self.file_path = file_path
        self.user = user
        self.transaction_model = VisaDesjardinsTransaction
        self.df = None

    def to_date(self, date_str):
        date_dict = {"MAI": 5, 'JUN': 6, 'JUL': 7, 'AOU': 8, 'SEP': 9, 'OCT': 10, 'JAN': 1, "FEV": 2, "MAR": 3, "AVR": 4}
        if isinstance(date_str, str):
            d_m = date_str.split()
            d = int(d_m[0])
            m = date_dict[d_m[1]]
            return datetime(2023, m, d)
        else:
            return np.nan

    def set_table_title(self, df):
        df.columns = df.iloc[1].to_list()
        df = df.iloc[3:]
        return df

    def format_columns(self, df):
        transaction_date_list = []
        record_date_list = []
        description_list = []
        rows_to_delete = []
        for k, data in df.iterrows():
            try:
                int(data["Description"][0:2])
                transaction_d=int(data["Description"][0:2])
                transaction_m=int(data["Description"][3:5])
                record_d = int(data["Description"][6:8])
                record_m = int(data["Description"][9:11])
                description = data["Description"][12:]
                transaction_date = datetime(2023, transaction_m, transaction_d)
                transaction_date_list.append(transaction_date)
                record_date = datetime(2023, record_m, record_d)
                record_date_list.append(record_date)
                description_list.append(description)
            except:
                   rows_to_delete.append(k)
        df = df.drop(rows_to_delete)
        df["transaction_date"] = transaction_date_list
        df["record_date"] = record_date_list
        df["description"] = description_list
        df.drop("Description", axis=1, inplace=True)
        
        # Convert columns to numeric
        df["BONIDOLLARS"] = pd.to_numeric(df["BONIDOLLARS"].str.replace(",", ".").str.replace("%", ""), errors="coerce")
        df["Montant"] = pd.to_numeric(df["Montant"].str.replace(",", "."), errors="coerce")
        df["BONIDOLLARS"] = df["BONIDOLLARS"] / 100
        
        columns_to_rename_dict = {"transaction_date": "date", 
                                  "description": "merchant", 
                                  "Montant": "amount"
                                 }
            
        df.rename(columns=columns_to_rename_dict, inplace=True)
            
        return df

    def process_dataframe(self, df):
        liste_colone_1 = ['Transactions effectuées avec la carte de : GENEVIEVE POITRAS', 'Unnamed: 0', 'Carte : 4540 33** **** 6028', 'Unnamed: 1']
        liste_colone_4 = ['Transactions effectuées avec la carte de : GENEVIEVE POITRAS', 'Carte : 4540 33** **** 6028', 'Unnamed: 0']
        liste_colone_2 = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Limite de crédit disponible : 12 000', 'Unnamed: 3', 'Unnamed: 4', "Taux d'intérêt"]
        liste_colone_3 = ['Unnamed: 0', 'Catégories', 'Unnamed: 1', 'BONIDOLLARS', '1 BONIDOLLAR accumulé = 1 $ à échanger']
        liste_colone_5 = ['Opérations au compte', '4540 33** **** 6002', 'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2']
        liste_colone_6 = ['Solde précédent', 'Unnamed: 0', 'Accumulés depuis', 'Unnamed: 1', 'Utilisés depuis', 'Unnamed: 2', 'Ajustements', 'Unnamed: 3', 'Total']
        df_copy = df.copy()
        if df_copy.columns.to_list() == liste_colone_1:
            df_copy = self.set_table_title(df_copy)
            d = self.format_columns(df_copy)
            d = d[['BONIDOLLARS', 'amount', 'date', 'record_date', 'merchant']]
        elif df_copy.columns.to_list() == liste_colone_4:
            df_copy = self.set_table_title(df_copy)
            d = self.format_columns(df_copy)
        else:
            d = pd.DataFrame()
        return d
        
    def create_transaction(self, df):
        transaction_list = []
        transaction_model = self.transaction_model
        
        
        for k, transaction_data in df.iterrows():
            for column_name in df.columns:
                transaction_instance = transaction_model()
                if hasattr(transaction_instance, column_name):
                    setattr(transaction_instance, column_name, transaction_data[column_name])
                
            transaction_instance.user = self.user
            transaction_list.append(transaction_instance)
            
        return transaction_list         
    
    def get_dfs_from_pdf(self):
        pdf_nested_dict = {}
        dfs = tabula.read_pdf(self.file_path, stream=True, pages="all")
        for index, df in enumerate(dfs):
            pdf_nested_dict[index] = df
        return pdf_nested_dict
    
    def get_processed_df_list(self):
        processed_df_list = []
        for k, df in self.get_dfs_from_pdf().items():
            processed_df_list.append(self.process_dataframe(df))
        return processed_df_list
    
    def get_transaction_list(self):
        transaction_list = []
        for processed_df in self.get_processed_df_list():
            if not processed_df.empty:
                print(processed_df.columns.to_list())
                transaction_list += self.create_transaction(processed_df)
        return transaction_list

# %%
u = "data/Desjardins/visa/454033600_20230524.pdf" 
v = VisaDesjardinsPdfTransactionProcessor(u, user)

# %%
l = v.get_transaction_list()
# Out:
# ['BONIDOLLARS', 'amount', 'date', 'record_date', 'merchant']
# ['BONIDOLLARS', 'amount', 'date', 'record_date', 'merchant']

# %%
dfs = v.get_processed_df_list()

# %%
for df in dfs:
    if not df.empty:
        for k, transaction_data in df.iterrows():
            transaction_instance = VisaDesjardinsTransaction()
            for column_name in df.columns:
                if hasattr(transaction_instance, column_name):
                    print(column_name, transaction_data[column_name])
                    setattr(transaction_instance, column_name, transaction_data[column_name])
            transaction_instance.user = user
            print("--------------", transaction_instance.__dict__)

            # transaction_instance.user = user
            # print(transaction_instance.amount)
# Out:
# BONIDOLLARS 0.005
# amount 25.55
# date 2023-04-25 00:00:00
# record_date 2023-04-25 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8b0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-25 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 25.55, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-04-25 00:00:00')}
# BONIDOLLARS 0.005
# amount 41.39
# date 2023-04-25 00:00:00
# record_date 2023-04-25 00:00:00
# merchant MAXI #8987 * POINTE-AUX-TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-25 00:00:00'), 'merchant': 'MAXI #8987 * POINTE-AUX-TRQC', 'amount': 41.39, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-04-25 00:00:00')}
# BONIDOLLARS 0.005
# amount 16.95
# date 2023-04-25 00:00:00
# record_date 2023-04-26 00:00:00
# merchant SAQ23106 DE LA POINTE POINTE-AUX-TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8b0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-25 00:00:00'), 'merchant': 'SAQ23106 DE LA POINTE POINTE-AUX-TRQC', 'amount': 16.95, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-04-26 00:00:00')}
# BONIDOLLARS 0.02
# amount 107.63
# date 2023-04-28 00:00:00
# record_date 2023-04-28 00:00:00
# merchant ALLO MON COCO PAT PTE AUX TREMBQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-28 00:00:00'), 'merchant': 'ALLO MON COCO PAT PTE AUX TREMBQC', 'amount': 107.63, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-04-28 00:00:00')}
# BONIDOLLARS 0.005
# amount 44.45
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe700>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 44.45, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 24.67
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant BRUNET PLUS ANJOU ANJOU QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8b0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'BRUNET PLUS ANJOU ANJOU QC', 'amount': 24.67, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 17.76
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe700>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'MARCHE ST JEAN BAPTI 2 POINTE AUX TRQC', 'amount': 17.76, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 29.33
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant ADONIS 21943 ANJOU ANJOU QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'ADONIS 21943 ANJOU ANJOU QC', 'amount': 29.33, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 23.54
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe700>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 23.54, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS nan
# amount nan
# date 2023-04-29 00:00:00
# record_date 2023-05-01 00:00:00
# merchant BRUNET PLUS ANJOU ANJOU QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbea90>, 'id': None, 'category_id': None, 'date': Timestamp('2023-04-29 00:00:00'), 'merchant': 'BRUNET PLUS ANJOU ANJOU QC', 'amount': nan, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': nan, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 4.59
# date 2023-05-01 00:00:00
# record_date 2023-05-01 00:00:00
# merchant MAXI #8987 * POINTE-AUX-TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-01 00:00:00'), 'merchant': 'MAXI #8987 * POINTE-AUX-TRQC', 'amount': 4.59, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-01 00:00:00')}
# BONIDOLLARS 0.005
# amount 4.99
# date 2023-05-02 00:00:00
# record_date 2023-05-02 00:00:00
# merchant METRO DE LA ROUSSELIER POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe700>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-02 00:00:00'), 'merchant': 'METRO DE LA ROUSSELIER POINTE AUX TRQC', 'amount': 4.99, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-02 00:00:00')}
# BONIDOLLARS 0.005
# amount 78.6
# date 2023-05-04 00:00:00
# record_date 2023-05-04 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-04 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 78.6, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-04 00:00:00')}
# BONIDOLLARS 0.005
# amount 31.09
# date 2023-05-04 00:00:00
# record_date 2023-05-04 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebb0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-04 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 31.09, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-04 00:00:00')}
# BONIDOLLARS 0.005
# amount 24.57
# date 2023-05-05 00:00:00
# record_date 2023-05-05 00:00:00
# merchant METRO DE LA ROUSSELIER POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-05 00:00:00'), 'merchant': 'METRO DE LA ROUSSELIER POINTE AUX TRQC', 'amount': 24.57, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-05 00:00:00')}
# BONIDOLLARS 0.005
# amount 14.5
# date 2023-05-06 00:00:00
# record_date 2023-05-08 00:00:00
# merchant MAXI & CIE REPENTIGNY REPENTIGNY QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8b0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-06 00:00:00'), 'merchant': 'MAXI & CIE REPENTIGNY REPENTIGNY QC', 'amount': 14.5, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-08 00:00:00')}
# BONIDOLLARS 0.005
# amount 40.28
# date 2023-05-07 00:00:00
# record_date 2023-05-08 00:00:00
# merchant METRO BEAUBIEN MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-07 00:00:00'), 'merchant': 'METRO BEAUBIEN MONTREAL QC', 'amount': 40.28, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-08 00:00:00')}
# BONIDOLLARS 0.005
# amount 7.99
# date 2023-05-07 00:00:00
# record_date 2023-05-08 00:00:00
# merchant IGA EXTRA 259 ST-LEONARD QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-07 00:00:00'), 'merchant': 'IGA EXTRA 259 ST-LEONARD QC', 'amount': 7.99, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-08 00:00:00')}
# BONIDOLLARS 0.005
# amount 114.34
# date 2023-05-08 00:00:00
# record_date 2023-05-08 00:00:00
# merchant SP MONTELLE INTIMATE MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-08 00:00:00'), 'merchant': 'SP MONTELLE INTIMATE MONTREAL QC', 'amount': 114.34, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-08 00:00:00')}
# BONIDOLLARS 0.005
# amount 7.98
# date 2023-05-08 00:00:00
# record_date 2023-05-08 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbec70>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-08 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 7.98, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-08 00:00:00')}
# BONIDOLLARS 0.005
# amount 37.0
# date 2023-05-10 00:00:00
# record_date 2023-05-10 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-10 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 37.0, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-10 00:00:00')}
# BONIDOLLARS 0.005
# amount 15.95
# date 2023-05-10 00:00:00
# record_date 2023-05-10 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe700>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-10 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 15.95, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-10 00:00:00')}
# BONIDOLLARS 0.005
# amount 12.33
# date 2023-05-10 00:00:00
# record_date 2023-05-11 00:00:00
# merchant IGA #8168 MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-10 00:00:00'), 'merchant': 'IGA #8168 MONTREAL QC', 'amount': 12.33, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-11 00:00:00')}
# BONIDOLLARS 0.02
# amount 19.84
# date 2023-05-10 00:00:00
# record_date 2023-05-11 00:00:00
# merchant LE LOUNGE SAINT-SAUVEURQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-10 00:00:00'), 'merchant': 'LE LOUNGE SAINT-SAUVEURQC', 'amount': 19.84, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-11 00:00:00')}
# BONIDOLLARS 0.005
# amount 211.82
# date 2023-05-10 00:00:00
# record_date 2023-05-12 00:00:00
# merchant MANOIR SAINT SAUVEUR 450-2271811 QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-10 00:00:00'), 'merchant': 'MANOIR SAINT SAUVEUR 450-2271811 QC', 'amount': 211.82, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-12 00:00:00')}
# BONIDOLLARS 0.02
# amount 10.86
# date 2023-05-11 00:00:00
# record_date 2023-05-11 00:00:00
# merchant ST-SAU PUB GOURMAND SAINT-SAUVEURQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8e0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-11 00:00:00'), 'merchant': 'ST-SAU PUB GOURMAND SAINT-SAUVEURQC', 'amount': 10.86, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-11 00:00:00')}
# BONIDOLLARS 0.005
# amount 21.16
# date 2023-05-13 00:00:00
# record_date 2023-05-15 00:00:00
# merchant SP JULES & HENRI MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-13 00:00:00'), 'merchant': 'SP JULES & HENRI MONTREAL QC', 'amount': 21.16, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 5.96
# date 2023-05-13 00:00:00
# record_date 2023-05-15 00:00:00
# merchant LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbeca0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-13 00:00:00'), 'merchant': 'LES FRAICHES - EPICERIE DPTE-AUX-TREMBQC', 'amount': 5.96, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 4.99
# date 2023-05-13 00:00:00
# record_date 2023-05-15 00:00:00
# merchant METRO DE LA ROUSSELIER POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-13 00:00:00'), 'merchant': 'METRO DE LA ROUSSELIER POINTE AUX TRQC', 'amount': 4.99, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.02
# amount 55.0
# date 2023-05-14 00:00:00
# record_date 2023-05-15 00:00:00
# merchant CAFE LES FRAICHES LASSOMPTION QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbea90>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-14 00:00:00'), 'merchant': 'CAFE LES FRAICHES LASSOMPTION QC', 'amount': 55.0, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 8.98
# date 2023-05-14 00:00:00
# record_date 2023-05-15 00:00:00
# merchant MAXI & CIE REPENTIGNY REPENTIGNY QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-14 00:00:00'), 'merchant': 'MAXI & CIE REPENTIGNY REPENTIGNY QC', 'amount': 8.98, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 15.95
# date 2023-05-14 00:00:00
# record_date 2023-05-15 00:00:00
# merchant SAQ23070 REPENTIGNY REPENTIGNY QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbec10>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-14 00:00:00'), 'merchant': 'SAQ23070 REPENTIGNY REPENTIGNY QC', 'amount': 15.95, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 16.65
# date 2023-05-15 00:00:00
# record_date 2023-05-15 00:00:00
# merchant METRO DE LA ROUSSELIER POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-15 00:00:00'), 'merchant': 'METRO DE LA ROUSSELIER POINTE AUX TRQC', 'amount': 16.65, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 69.27
# date 2023-05-15 00:00:00
# record_date 2023-05-15 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-15 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 69.27, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-15 00:00:00')}
# BONIDOLLARS 0.005
# amount 49.25
# date 2023-05-17 00:00:00
# record_date 2023-05-17 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-17 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 49.25, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-17 00:00:00')}
# BONIDOLLARS 0.005
# amount 1.48
# date 2023-05-17 00:00:00
# record_date 2023-05-17 00:00:00
# merchant APPLE.COM/BILL 866-712-7753 ON
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbeca0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-17 00:00:00'), 'merchant': 'APPLE.COM/BILL 866-712-7753 ON', 'amount': 1.48, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-17 00:00:00')}
# BONIDOLLARS 0.005
# amount 15.55
# date 2023-05-18 00:00:00
# record_date 2023-05-18 00:00:00
# merchant SAQ23106CARREFOUR DE LA MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-18 00:00:00'), 'merchant': 'SAQ23106CARREFOUR DE LA MONTREAL QC', 'amount': 15.55, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-18 00:00:00')}
# BONIDOLLARS 0.02
# amount 50.24
# date 2023-05-18 00:00:00
# record_date 2023-05-19 00:00:00
# merchant LES INSULAIRES MICROBRA LAVAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbec70>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-18 00:00:00'), 'merchant': 'LES INSULAIRES MICROBRA LAVAL QC', 'amount': 50.24, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-19 00:00:00')}
# BONIDOLLARS 0.005
# amount 30.53
# date 2023-05-19 00:00:00
# record_date 2023-05-19 00:00:00
# merchant METRO DE LA ROUSSELIER POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-19 00:00:00'), 'merchant': 'METRO DE LA ROUSSELIER POINTE AUX TRQC', 'amount': 30.53, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-19 00:00:00')}
# BONIDOLLARS 0.005
# amount 71.07
# date 2023-05-19 00:00:00
# record_date 2023-05-19 00:00:00
# merchant SUPER C PAT 5963 POINTE AUX TRQC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe640>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-19 00:00:00'), 'merchant': 'SUPER C PAT 5963 POINTE AUX TRQC', 'amount': 71.07, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-19 00:00:00')}
# BONIDOLLARS 0.005
# amount 9.52
# date 2023-05-19 00:00:00
# record_date 2023-05-19 00:00:00
# merchant MAXI #8622 TERREBONNE QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbea90>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-19 00:00:00'), 'merchant': 'MAXI #8622 TERREBONNE QC', 'amount': 9.52, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-19 00:00:00')}
# BONIDOLLARS 0.005
# amount 69.65
# date 2023-05-19 00:00:00
# record_date 2023-05-19 00:00:00
# merchant SAQ23004 BROSSARD QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbebe0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-19 00:00:00'), 'merchant': 'SAQ23004 BROSSARD QC', 'amount': 69.65, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-19 00:00:00')}
# BONIDOLLARS 0.02
# amount 72.07
# date 2023-05-21 00:00:00
# record_date 2023-05-23 00:00:00
# merchant MICROBRASSERIE LA MEMPH MAGOG QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-21 00:00:00'), 'merchant': 'MICROBRASSERIE LA MEMPH MAGOG QC', 'amount': 72.07, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-23 00:00:00')}
# BONIDOLLARS 0.005
# amount 284.78
# date 2023-05-22 00:00:00
# record_date 2023-05-23 00:00:00
# merchant RW #2499 MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe8e0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-22 00:00:00'), 'merchant': 'RW #2499 MONTREAL QC', 'amount': 284.78, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-23 00:00:00')}
# BONIDOLLARS 0.02
# amount 20.77
# date 2023-05-22 00:00:00
# record_date 2023-05-23 00:00:00
# merchant MCDONALD'S #18127 QPS ANGE-GARDIEN QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbea90>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-22 00:00:00'), 'merchant': "MCDONALD'S #18127 QPS ANGE-GARDIEN QC", 'amount': 20.77, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-23 00:00:00')}
# BONIDOLLARS 0.005
# amount 1.4
# date 2023-05-22 00:00:00
# record_date 2023-05-23 00:00:00
# merchant AGENCE DE MOBILITE DURABLMONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbe610>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-22 00:00:00'), 'merchant': 'AGENCE DE MOBILITE DURABLMONTREAL QC', 'amount': 1.4, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.005, 'record_date': Timestamp('2023-05-23 00:00:00')}
# BONIDOLLARS 0.02
# amount 25.3
# date 2023-05-24 00:00:00
# record_date 2023-05-24 00:00:00
# merchant LE POKE STATION PAT MONTREAL QC
# -------------- {'_state': <django.db.models.base.ModelState object at 0x13fdbeca0>, 'id': None, 'category_id': None, 'date': Timestamp('2023-05-24 00:00:00'), 'merchant': 'LE POKE STATION PAT MONTREAL QC', 'amount': 25.3, 'note': '', 'source_id': None, 'user_id': 1, 'is_completed': False, 'transaction_ptr_id': None, 'BONIDOLLARS': 0.02, 'record_date': Timestamp('2023-05-24 00:00:00')}
